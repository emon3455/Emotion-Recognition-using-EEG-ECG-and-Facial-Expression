# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout,
                                     Concatenate, BatchNormalization, Conv1D, MaxPooling1D)
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.utils import resample
from tensorflow.keras.utils import to_categorical

# Load and duplicate dataset
data_path = '/content/drive/MyDrive/dataset/preprocessed-data/mahnob_HCI_preprocessed_all.npy'
data = np.load(data_path, allow_pickle=True)

# Extract features and labels
X_eeg = np.array([entry['eeg_data'] for entry in data])
X_video = np.array([entry['video_data'] for entry in data])
X_ecg = np.array([entry['ecg_data'] for entry in data])
y = np.array([entry['labels'] for entry in data])

print(f"Number of samples: {len(data)}")

# Video padding if needed
if X_video.shape[1:] != (32, 64, 64):
    padded_video = []
    for video in X_video:
        pad_shape = [
            (0, max(0, 32 - video.shape[0])),
            (0, max(0, 64 - video.shape[1])),
            (0, max(0, 64 - video.shape[2]))
        ]
        padded_video.append(np.pad(video, pad_shape, mode='constant'))
    X_video = np.array(padded_video)

# Class balancing
def balance_classes(X1, X2, X3, y, class_idx):
    labels = y[:, class_idx]
    unique_classes, class_counts = np.unique(labels, return_counts=True)
    max_count = np.max(class_counts)
    balanced_X1, balanced_X2, balanced_X3, balanced_y = [], [], [], []
    for cls in unique_classes:
        cls_mask = labels == cls
        cls_X1, cls_X2, cls_X3, cls_y = X1[cls_mask], X2[cls_mask], X3[cls_mask], y[cls_mask]
        if len(cls_y) < max_count:
            X1_oversampled, X2_oversampled, X3_oversampled, y_oversampled = resample(
                cls_X1, cls_X2, cls_X3, cls_y,
                replace=True,
                n_samples=max_count - len(cls_y),
                random_state=42
            )
            cls_X1 = np.concatenate([cls_X1, X1_oversampled])
            cls_X2 = np.concatenate([cls_X2, X2_oversampled])
            cls_X3 = np.concatenate([cls_X3, X3_oversampled])
            cls_y = np.concatenate([cls_y, y_oversampled])
        balanced_X1.append(cls_X1)
        balanced_X2.append(cls_X2)
        balanced_X3.append(cls_X3)
        balanced_y.append(cls_y)
    return (np.concatenate(balanced_X1),
            np.concatenate(balanced_X2),
            np.concatenate(balanced_X3),
            np.concatenate(balanced_y))

X_eeg, X_video, X_ecg, y = balance_classes(X_eeg, X_video, X_ecg, y, class_idx=1)
X_eeg, X_video, X_ecg, y = balance_classes(X_eeg, X_video, X_ecg, y, class_idx=2)

# Split data
X_eeg_train, X_eeg_test, X_video_train, X_video_test, X_ecg_train, X_ecg_test, y_train, y_test = train_test_split(
    X_eeg, X_video, X_ecg, y, test_size=0.2, random_state=42
)

num_valence_classes = int(np.max(y[:, 1])) + 1
num_arousal_classes = int(np.max(y[:, 2])) + 1

y_valence_train = to_categorical(y_train[:, 1], num_classes=num_valence_classes)
y_arousal_train = to_categorical(y_train[:, 2], num_classes=num_arousal_classes)
y_valence_test = to_categorical(y_test[:, 1], num_classes=num_valence_classes)
y_arousal_test = to_categorical(y_test[:, 2], num_classes=num_arousal_classes)

# --------- 2D CNN BRANCH (single facial frame per video) ----------
X_video_train_2d = X_video_train[:, 0, :, :][..., np.newaxis]
X_video_test_2d  = X_video_test[:, 0, :, :][..., np.newaxis]

video_input = Input(shape=(64, 64, 1), name="video_input")
x = Conv2D(32, (3, 3), activation='relu', padding='same')(video_input)
x = MaxPooling2D((2, 2))(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2))(x)
x = BatchNormalization()(x)
x = Flatten()(x)
cnn_output = Dense(128, activation='relu')(x)

# --------- 1D CNN EEG BRANCH ---------
# Transpose: (samples, channels, time) -> (samples, time, channels)
X_eeg_train_1d = np.transpose(X_eeg_train, (0, 2, 1))
X_eeg_test_1d = np.transpose(X_eeg_test, (0, 2, 1))
eeg_input = Input(shape=(512, 5), name="eeg_input")
eeg_cnn = Conv1D(64, 7, activation='relu', padding='same')(eeg_input)
eeg_cnn = MaxPooling1D(2)(eeg_cnn)
eeg_cnn = BatchNormalization()(eeg_cnn)
eeg_cnn = Conv1D(128, 5, activation='relu', padding='same')(eeg_cnn)
eeg_cnn = MaxPooling1D(2)(eeg_cnn)
eeg_cnn = BatchNormalization()(eeg_cnn)
eeg_cnn = Flatten()(eeg_cnn)
eeg_output = Dense(128, activation='relu')(eeg_cnn)

# --------- 1D CNN ECG BRANCH ---------
# Transpose: (samples, channels, time) -> (samples, time, channels)
X_ecg_train_1d = np.transpose(X_ecg_train, (0, 2, 1))
X_ecg_test_1d = np.transpose(X_ecg_test, (0, 2, 1))
ecg_input = Input(shape=(512, 2), name="ecg_input")
ecg_cnn = Conv1D(64, 7, activation='relu', padding='same')(ecg_input)
ecg_cnn = MaxPooling1D(2)(ecg_cnn)
ecg_cnn = BatchNormalization()(ecg_cnn)
ecg_cnn = Conv1D(128, 5, activation='relu', padding='same')(ecg_cnn)
ecg_cnn = MaxPooling1D(2)(ecg_cnn)
ecg_cnn = BatchNormalization()(ecg_cnn)
ecg_cnn = Flatten()(ecg_cnn)
ecg_output = Dense(64, activation='relu')(ecg_cnn)

# --------- FUSION AND OUTPUT ---------
combined = Concatenate()([cnn_output, eeg_output, ecg_output])
combined = Dense(256, activation='relu')(combined)
combined = Dropout(0.3)(combined)
combined = Dense(128, activation='relu')(combined)
combined = Dropout(0.2)(combined)

valence_output = Dense(num_valence_classes, activation='softmax', name="valence_output")(combined)
arousal_output = Dense(num_arousal_classes, activation='softmax', name="arousal_output")(combined)

model = Model(
    inputs=[video_input, eeg_input, ecg_input],
    outputs=[valence_output, arousal_output]
)

model.compile(
    optimizer='adam',
    loss=['categorical_crossentropy', 'categorical_crossentropy'],
    metrics=['accuracy', 'accuracy']
)
model.summary()

# Train
history = model.fit(
    [X_video_train_2d, X_eeg_train_1d, X_ecg_train_1d],
    [y_valence_train, y_arousal_train],
    validation_data=(
        [X_video_test_2d, X_eeg_test_1d, X_ecg_test_1d],
        [y_valence_test, y_arousal_test]
    ),
    epochs=50,
    batch_size=128
)

# Evaluate
y_valence_pred, y_arousal_pred = model.predict([X_video_test_2d, X_eeg_test_1d, X_ecg_test_1d])
y_valence_pred_classes = np.argmax(y_valence_pred, axis=1)
y_arousal_pred_classes = np.argmax(y_arousal_pred, axis=1)
y_valence_true = np.argmax(y_valence_test, axis=1)
y_arousal_true = np.argmax(y_arousal_test, axis=1)

valence_accuracy = accuracy_score(y_valence_true, y_valence_pred_classes)
arousal_accuracy = accuracy_score(y_arousal_true, y_arousal_pred_classes)

print(f"Valence Accuracy: {valence_accuracy * 100:.2f}%")
print(f"Arousal Accuracy: {arousal_accuracy * 100:.2f}%")
# Out:
# Number of samples: 186
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ video_input         │ (None, 64, 64, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ eeg_input           │ (None, 512, 5)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ecg_input           │ (None, 512, 2)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │        320 │ video_input[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 512, 64)   │      2,304 │ eeg_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 512, 64)   │        960 │ ecg_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_4     │ (None, 256, 64)   │          0 │ conv1d_4[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_6     │ (None, 256, 64)   │          0 │ conv1d_6[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ max_pooling2d_2[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 64)   │        256 │ max_pooling1d_4[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 64)   │        256 │ max_pooling1d_6[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │     18,496 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 256, 128)  │     41,088 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 256, 128)  │     41,088 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_5     │ (None, 128, 128)  │          0 │ conv1d_5[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_7     │ (None, 128, 128)  │          0 │ conv1d_7[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ max_pooling2d_3[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128)  │        512 │ max_pooling1d_5[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128)  │        512 │ max_pooling1d_7[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 16384)     │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_4 (Flatten) │ (None, 16384)     │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_5 (Flatten) │ (None, 16384)     │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │  2,097,280 │ flatten_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │  2,097,280 │ flatten_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 64)        │  1,048,640 │ flatten_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 320)       │          0 │ dense_5[0][0],    │
# │ (Concatenate)       │                   │            │ dense_6[0][0],    │
# │                     │                   │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 256)       │     82,176 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 128)       │     32,896 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ valence_output      │ (None, 10)        │      1,290 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ arousal_output      │ (None, 10)        │      1,290 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,467,028 (20.86 MB)
#  Trainable params: 5,466,068 (20.85 MB)
#  Non-trainable params: 960 (3.75 KB)
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - arousal_output_accuracy: 0.1062 - arousal_output_loss: 4.4630 - loss: 8.0113 - valence_output_accuracy: 0.1203 - valence_output_loss: 3.5556 - val_arousal_output_accuracy: 0.0426 - val_arousal_output_loss: 3.2281 - val_loss: 5.7058 - val_valence_output_accuracy: 0.1596 - val_valence_output_loss: 2.4777
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - arousal_output_accuracy: 0.1695 - arousal_output_loss: 3.3707 - loss: 6.6665 - valence_output_accuracy: 0.1449 - valence_output_loss: 3.2816 - val_arousal_output_accuracy: 0.1170 - val_arousal_output_loss: 2.5623 - val_loss: 4.8169 - val_valence_output_accuracy: 0.1170 - val_valence_output_loss: 2.2546
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - arousal_output_accuracy: 0.2446 - arousal_output_loss: 2.2407 - loss: 4.5841 - valence_output_accuracy: 0.1813 - valence_output_loss: 2.3406 - val_arousal_output_accuracy: 0.1702 - val_arousal_output_loss: 2.7886 - val_loss: 4.9383 - val_valence_output_accuracy: 0.2447 - val_valence_output_loss: 2.1497
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - arousal_output_accuracy: 0.3069 - arousal_output_loss: 1.9850 - loss: 3.9402 - valence_output_accuracy: 0.3201 - valence_output_loss: 1.9511 - val_arousal_output_accuracy: 0.1170 - val_arousal_output_loss: 3.8253 - val_loss: 6.1028 - val_valence_output_accuracy: 0.2766 - val_valence_output_loss: 2.2775
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - arousal_output_accuracy: 0.3842 - arousal_output_loss: 1.7386 - loss: 3.5256 - valence_output_accuracy: 0.3629 - valence_output_loss: 1.7868 - val_arousal_output_accuracy: 0.1489 - val_arousal_output_loss: 3.4336 - val_loss: 5.6572 - val_valence_output_accuracy: 0.2340 - val_valence_output_loss: 2.2236
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - arousal_output_accuracy: 0.4359 - arousal_output_loss: 1.5587 - loss: 3.1688 - valence_output_accuracy: 0.4486 - valence_output_loss: 1.6093 - val_arousal_output_accuracy: 0.1702 - val_arousal_output_loss: 2.6967 - val_loss: 4.8267 - val_valence_output_accuracy: 0.2234 - val_valence_output_loss: 2.1300
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - arousal_output_accuracy: 0.4956 - arousal_output_loss: 1.4554 - loss: 2.9245 - valence_output_accuracy: 0.4606 - valence_output_loss: 1.4684 - val_arousal_output_accuracy: 0.2234 - val_arousal_output_loss: 2.3246 - val_loss: 4.3315 - val_valence_output_accuracy: 0.2660 - val_valence_output_loss: 2.0069
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - arousal_output_accuracy: 0.5580 - arousal_output_loss: 1.3430 - loss: 2.6590 - valence_output_accuracy: 0.5379 - valence_output_loss: 1.3165 - val_arousal_output_accuracy: 0.3511 - val_arousal_output_loss: 2.0158 - val_loss: 3.8914 - val_valence_output_accuracy: 0.3191 - val_valence_output_loss: 1.8756
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - arousal_output_accuracy: 0.5799 - arousal_output_loss: 1.1592 - loss: 2.3987 - valence_output_accuracy: 0.5759 - valence_output_loss: 1.2397 - val_arousal_output_accuracy: 0.3723 - val_arousal_output_loss: 1.8886 - val_loss: 3.6698 - val_valence_output_accuracy: 0.3830 - val_valence_output_loss: 1.7812
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - arousal_output_accuracy: 0.6244 - arousal_output_loss: 1.0977 - loss: 2.2604 - valence_output_accuracy: 0.5923 - valence_output_loss: 1.1613 - val_arousal_output_accuracy: 0.4149 - val_arousal_output_loss: 1.8545 - val_loss: 3.5870 - val_valence_output_accuracy: 0.4362 - val_valence_output_loss: 1.7325
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - arousal_output_accuracy: 0.6759 - arousal_output_loss: 0.9970 - loss: 2.0435 - valence_output_accuracy: 0.6053 - valence_output_loss: 1.0453 - val_arousal_output_accuracy: 0.4149 - val_arousal_output_loss: 1.6885 - val_loss: 3.2992 - val_valence_output_accuracy: 0.4894 - val_valence_output_loss: 1.6107
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - arousal_output_accuracy: 0.7373 - arousal_output_loss: 0.8367 - loss: 1.6815 - valence_output_accuracy: 0.7165 - valence_output_loss: 0.8429 - val_arousal_output_accuracy: 0.4787 - val_arousal_output_loss: 1.5755 - val_loss: 3.1117 - val_valence_output_accuracy: 0.4681 - val_valence_output_loss: 1.5362
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - arousal_output_accuracy: 0.6968 - arousal_output_loss: 0.8337 - loss: 1.6319 - valence_output_accuracy: 0.7204 - valence_output_loss: 0.7973 - val_arousal_output_accuracy: 0.5319 - val_arousal_output_loss: 1.4458 - val_loss: 2.9196 - val_valence_output_accuracy: 0.5319 - val_valence_output_loss: 1.4738
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - arousal_output_accuracy: 0.8191 - arousal_output_loss: 0.6041 - loss: 1.2907 - valence_output_accuracy: 0.7579 - valence_output_loss: 0.6890 - val_arousal_output_accuracy: 0.5532 - val_arousal_output_loss: 1.3686 - val_loss: 2.7740 - val_valence_output_accuracy: 0.5851 - val_valence_output_loss: 1.4054
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - arousal_output_accuracy: 0.8167 - arousal_output_loss: 0.5443 - loss: 1.1147 - valence_output_accuracy: 0.8404 - valence_output_loss: 0.5722 - val_arousal_output_accuracy: 0.6064 - val_arousal_output_loss: 1.2799 - val_loss: 2.5894 - val_valence_output_accuracy: 0.6383 - val_valence_output_loss: 1.3095
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - arousal_output_accuracy: 0.8495 - arousal_output_loss: 0.4767 - loss: 0.9558 - valence_output_accuracy: 0.8401 - valence_output_loss: 0.4795 - val_arousal_output_accuracy: 0.6915 - val_arousal_output_loss: 1.1966 - val_loss: 2.4408 - val_valence_output_accuracy: 0.6596 - val_valence_output_loss: 1.2442
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - arousal_output_accuracy: 0.8461 - arousal_output_loss: 0.4811 - loss: 1.0168 - valence_output_accuracy: 0.8225 - valence_output_loss: 0.5355 - val_arousal_output_accuracy: 0.7021 - val_arousal_output_loss: 1.1306 - val_loss: 2.3351 - val_valence_output_accuracy: 0.6596 - val_valence_output_loss: 1.2045
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - arousal_output_accuracy: 0.8927 - arousal_output_loss: 0.3392 - loss: 0.7932 - valence_output_accuracy: 0.8470 - valence_output_loss: 0.4533 - val_arousal_output_accuracy: 0.6915 - val_arousal_output_loss: 1.0606 - val_loss: 2.1926 - val_valence_output_accuracy: 0.6596 - val_valence_output_loss: 1.1320
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - arousal_output_accuracy: 0.8958 - arousal_output_loss: 0.3168 - loss: 0.6976 - valence_output_accuracy: 0.8782 - valence_output_loss: 0.3780 - val_arousal_output_accuracy: 0.7128 - val_arousal_output_loss: 1.0317 - val_loss: 2.1296 - val_valence_output_accuracy: 0.6915 - val_valence_output_loss: 1.0978
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - arousal_output_accuracy: 0.8933 - arousal_output_loss: 0.3503 - loss: 0.6901 - valence_output_accuracy: 0.8975 - valence_output_loss: 0.3380 - val_arousal_output_accuracy: 0.7447 - val_arousal_output_loss: 0.9970 - val_loss: 2.0546 - val_valence_output_accuracy: 0.7021 - val_valence_output_loss: 1.0576
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - arousal_output_accuracy: 0.8865 - arousal_output_loss: 0.3236 - loss: 0.5653 - valence_output_accuracy: 0.9376 - valence_output_loss: 0.2419 - val_arousal_output_accuracy: 0.7660 - val_arousal_output_loss: 0.9224 - val_loss: 1.9370 - val_valence_output_accuracy: 0.7340 - val_valence_output_loss: 1.0146
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - arousal_output_accuracy: 0.9258 - arousal_output_loss: 0.2361 - loss: 0.4485 - valence_output_accuracy: 0.9300 - valence_output_loss: 0.2130 - val_arousal_output_accuracy: 0.8085 - val_arousal_output_loss: 0.8805 - val_loss: 1.8870 - val_valence_output_accuracy: 0.7021 - val_valence_output_loss: 1.0065
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - arousal_output_accuracy: 0.9456 - arousal_output_loss: 0.1956 - loss: 0.4143 - valence_output_accuracy: 0.9284 - valence_output_loss: 0.2191 - val_arousal_output_accuracy: 0.8085 - val_arousal_output_loss: 0.8499 - val_loss: 1.8322 - val_valence_output_accuracy: 0.7128 - val_valence_output_loss: 0.9823
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - arousal_output_accuracy: 0.9091 - arousal_output_loss: 0.1917 - loss: 0.3631 - valence_output_accuracy: 0.9479 - valence_output_loss: 0.1704 - val_arousal_output_accuracy: 0.7979 - val_arousal_output_loss: 0.8429 - val_loss: 1.8113 - val_valence_output_accuracy: 0.7021 - val_valence_output_loss: 0.9683
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - arousal_output_accuracy: 0.9393 - arousal_output_loss: 0.1687 - loss: 0.3407 - valence_output_accuracy: 0.9401 - valence_output_loss: 0.1712 - val_arousal_output_accuracy: 0.8191 - val_arousal_output_loss: 0.8020 - val_loss: 1.7520 - val_valence_output_accuracy: 0.7340 - val_valence_output_loss: 0.9500
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - arousal_output_accuracy: 0.9588 - arousal_output_loss: 0.1635 - loss: 0.3258 - valence_output_accuracy: 0.9602 - valence_output_loss: 0.1621 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.7684 - val_loss: 1.6580 - val_valence_output_accuracy: 0.7553 - val_valence_output_loss: 0.8896
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - arousal_output_accuracy: 0.9644 - arousal_output_loss: 0.1261 - loss: 0.2712 - valence_output_accuracy: 0.9569 - valence_output_loss: 0.1447 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.7391 - val_loss: 1.5985 - val_valence_output_accuracy: 0.7766 - val_valence_output_loss: 0.8594
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - arousal_output_accuracy: 0.9418 - arousal_output_loss: 0.1629 - loss: 0.2902 - valence_output_accuracy: 0.9525 - valence_output_loss: 0.1266 - val_arousal_output_accuracy: 0.8404 - val_arousal_output_loss: 0.7290 - val_loss: 1.5296 - val_valence_output_accuracy: 0.8191 - val_valence_output_loss: 0.8007
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - arousal_output_accuracy: 0.9647 - arousal_output_loss: 0.1041 - loss: 0.2353 - valence_output_accuracy: 0.9499 - valence_output_loss: 0.1309 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.7217 - val_loss: 1.4812 - val_valence_output_accuracy: 0.8191 - val_valence_output_loss: 0.7595
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - arousal_output_accuracy: 0.9657 - arousal_output_loss: 0.1276 - loss: 0.2485 - valence_output_accuracy: 0.9697 - valence_output_loss: 0.1207 - val_arousal_output_accuracy: 0.7979 - val_arousal_output_loss: 0.7377 - val_loss: 1.4801 - val_valence_output_accuracy: 0.8191 - val_valence_output_loss: 0.7424
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - arousal_output_accuracy: 0.9762 - arousal_output_loss: 0.0792 - loss: 0.1731 - valence_output_accuracy: 0.9594 - valence_output_loss: 0.0936 - val_arousal_output_accuracy: 0.7766 - val_arousal_output_loss: 0.7316 - val_loss: 1.4636 - val_valence_output_accuracy: 0.8085 - val_valence_output_loss: 0.7320
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - arousal_output_accuracy: 0.9604 - arousal_output_loss: 0.1010 - loss: 0.1794 - valence_output_accuracy: 0.9812 - valence_output_loss: 0.0783 - val_arousal_output_accuracy: 0.7553 - val_arousal_output_loss: 0.7003 - val_loss: 1.4229 - val_valence_output_accuracy: 0.7872 - val_valence_output_loss: 0.7225
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - arousal_output_accuracy: 0.9483 - arousal_output_loss: 0.1166 - loss: 0.2307 - valence_output_accuracy: 0.9648 - valence_output_loss: 0.1134 - val_arousal_output_accuracy: 0.8191 - val_arousal_output_loss: 0.6947 - val_loss: 1.4131 - val_valence_output_accuracy: 0.7872 - val_valence_output_loss: 0.7183
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - arousal_output_accuracy: 0.9851 - arousal_output_loss: 0.0445 - loss: 0.1158 - valence_output_accuracy: 0.9861 - valence_output_loss: 0.0717 - val_arousal_output_accuracy: 0.8191 - val_arousal_output_loss: 0.7004 - val_loss: 1.4069 - val_valence_output_accuracy: 0.7766 - val_valence_output_loss: 0.7065
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - arousal_output_accuracy: 0.9694 - arousal_output_loss: 0.0767 - loss: 0.1384 - valence_output_accuracy: 0.9786 - valence_output_loss: 0.0622 - val_arousal_output_accuracy: 0.8191 - val_arousal_output_loss: 0.7086 - val_loss: 1.4208 - val_valence_output_accuracy: 0.7766 - val_valence_output_loss: 0.7122
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - arousal_output_accuracy: 0.9878 - arousal_output_loss: 0.0453 - loss: 0.0902 - valence_output_accuracy: 0.9878 - valence_output_loss: 0.0449 - val_arousal_output_accuracy: 0.8191 - val_arousal_output_loss: 0.6823 - val_loss: 1.3777 - val_valence_output_accuracy: 0.7766 - val_valence_output_loss: 0.6954
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - arousal_output_accuracy: 0.9759 - arousal_output_loss: 0.0621 - loss: 0.1175 - valence_output_accuracy: 0.9828 - valence_output_loss: 0.0557 - val_arousal_output_accuracy: 0.8191 - val_arousal_output_loss: 0.6593 - val_loss: 1.3372 - val_valence_output_accuracy: 0.7979 - val_valence_output_loss: 0.6779
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - arousal_output_accuracy: 0.9921 - arousal_output_loss: 0.0273 - loss: 0.0918 - valence_output_accuracy: 0.9865 - valence_output_loss: 0.0647 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.6448 - val_loss: 1.3028 - val_valence_output_accuracy: 0.7979 - val_valence_output_loss: 0.6580
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - arousal_output_accuracy: 0.9805 - arousal_output_loss: 0.0544 - loss: 0.1052 - valence_output_accuracy: 0.9855 - valence_output_loss: 0.0505 - val_arousal_output_accuracy: 0.8085 - val_arousal_output_loss: 0.6348 - val_loss: 1.2964 - val_valence_output_accuracy: 0.8191 - val_valence_output_loss: 0.6615
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - arousal_output_accuracy: 0.9747 - arousal_output_loss: 0.0854 - loss: 0.1357 - valence_output_accuracy: 0.9884 - valence_output_loss: 0.0501 - val_arousal_output_accuracy: 0.8191 - val_arousal_output_loss: 0.6408 - val_loss: 1.3500 - val_valence_output_accuracy: 0.7872 - val_valence_output_loss: 0.7092
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - arousal_output_accuracy: 0.9927 - arousal_output_loss: 0.0251 - loss: 0.0727 - valence_output_accuracy: 0.9822 - valence_output_loss: 0.0477 - val_arousal_output_accuracy: 0.8191 - val_arousal_output_loss: 0.6536 - val_loss: 1.4056 - val_valence_output_accuracy: 0.7979 - val_valence_output_loss: 0.7520
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - arousal_output_accuracy: 0.9812 - arousal_output_loss: 0.0491 - loss: 0.0875 - valence_output_accuracy: 0.9927 - valence_output_loss: 0.0382 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.6472 - val_loss: 1.4396 - val_valence_output_accuracy: 0.7979 - val_valence_output_loss: 0.7924
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - arousal_output_accuracy: 0.9834 - arousal_output_loss: 0.0358 - loss: 0.0937 - valence_output_accuracy: 0.9826 - valence_output_loss: 0.0578 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.6518 - val_loss: 1.4382 - val_valence_output_accuracy: 0.7872 - val_valence_output_loss: 0.7864
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - arousal_output_accuracy: 0.9907 - arousal_output_loss: 0.0372 - loss: 0.0814 - valence_output_accuracy: 0.9783 - valence_output_loss: 0.0440 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.6396 - val_loss: 1.4032 - val_valence_output_accuracy: 0.7979 - val_valence_output_loss: 0.7637
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - arousal_output_accuracy: 0.9884 - arousal_output_loss: 0.0532 - loss: 0.1096 - valence_output_accuracy: 0.9848 - valence_output_loss: 0.0567 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.6244 - val_loss: 1.3649 - val_valence_output_accuracy: 0.7766 - val_valence_output_loss: 0.7405
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - arousal_output_accuracy: 0.9776 - arousal_output_loss: 0.0701 - loss: 0.0941 - valence_output_accuracy: 0.9973 - valence_output_loss: 0.0241 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.6291 - val_loss: 1.3517 - val_valence_output_accuracy: 0.7766 - val_valence_output_loss: 0.7226
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - arousal_output_accuracy: 0.9973 - arousal_output_loss: 0.0239 - loss: 0.0606 - valence_output_accuracy: 0.9927 - valence_output_loss: 0.0370 - val_arousal_output_accuracy: 0.8404 - val_arousal_output_loss: 0.6408 - val_loss: 1.3531 - val_valence_output_accuracy: 0.7766 - val_valence_output_loss: 0.7123
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - arousal_output_accuracy: 0.9973 - arousal_output_loss: 0.0118 - loss: 0.0504 - valence_output_accuracy: 0.9907 - valence_output_loss: 0.0391 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.6505 - val_loss: 1.3563 - val_valence_output_accuracy: 0.7660 - val_valence_output_loss: 0.7058
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - arousal_output_accuracy: 0.9973 - arousal_output_loss: 0.0165 - loss: 0.0517 - valence_output_accuracy: 0.9865 - valence_output_loss: 0.0356 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.6489 - val_loss: 1.3560 - val_valence_output_accuracy: 0.7766 - val_valence_output_loss: 0.7071
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - arousal_output_accuracy: 0.9921 - arousal_output_loss: 0.0243 - loss: 0.0699 - valence_output_accuracy: 0.9892 - valence_output_loss: 0.0453 - val_arousal_output_accuracy: 0.8404 - val_arousal_output_loss: 0.6824 - val_loss: 1.3974 - val_valence_output_accuracy: 0.7766 - val_valence_output_loss: 0.7150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step
# Valence Accuracy: 77.66%
# Arousal Accuracy: 84.04%
