# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **With Duplicate**

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, LSTM, Dropout, Concatenate, BatchNormalization, Lambda
)
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.utils import resample
from tensorflow.keras.utils import to_categorical

# ----------- DATA LOADING & DUPLICATION -----------
data_path = '/content/drive/MyDrive/dataset/preprocessed-data/mahnob_HCI_preprocessed_all.npy'
data = np.load(data_path, allow_pickle=True)

def duplicate_dataset(data, num_duplicates):
    duplicated_data = data.tolist()
    for _ in range(num_duplicates):
        duplicated_data.extend(data.tolist())
    return np.array(duplicated_data)

num_duplicates = 1
data = duplicate_dataset(data, num_duplicates)

# ----------- FEATURES AND LABELS -----------
X_eeg   = np.array([entry['eeg_data']  for entry in data])
X_video = np.array([entry['video_data'] for entry in data]) # (N, 32, 64, 64)
X_ecg   = np.array([entry['ecg_data']  for entry in data])
y       = np.array([entry['labels']    for entry in data])
print(f"Number of samples after duplication: {len(data)}")

# Pad video data if needed
if X_video.shape[1:] != (32, 64, 64):
    padded_video = []
    for video in X_video:
        pad_shape = [
            (0, max(0, 32 - video.shape[0])),
            (0, max(0, 64 - video.shape[1])),
            (0, max(0, 64 - video.shape[2]))
        ]
        padded_video.append(np.pad(video, pad_shape, mode='constant'))
    X_video = np.array(padded_video)

# ----------- CLASS BALANCING -----------
def balance_classes(X1, X2, X3, y, class_idx):
    labels = y[:, class_idx]
    unique_classes, class_counts = np.unique(labels, return_counts=True)
    max_count = np.max(class_counts)

    balanced_X1, balanced_X2, balanced_X3, balanced_y = [], [], [], []
    for cls in unique_classes:
        cls_mask = labels == cls
        cls_X1, cls_X2, cls_X3, cls_y = X1[cls_mask], X2[cls_mask], X3[cls_mask], y[cls_mask]

        if len(cls_y) < max_count:
            X1_oversampled, X2_oversampled, X3_oversampled, y_oversampled = resample(
                cls_X1, cls_X2, cls_X3, cls_y, replace=True,
                n_samples=max_count - len(cls_y), random_state=42)
            cls_X1 = np.concatenate([cls_X1, X1_oversampled])
            cls_X2 = np.concatenate([cls_X2, X2_oversampled])
            cls_X3 = np.concatenate([cls_X3, X3_oversampled])
            cls_y  = np.concatenate([cls_y,  y_oversampled])
        balanced_X1.append(cls_X1)
        balanced_X2.append(cls_X2)
        balanced_X3.append(cls_X3)
        balanced_y.append(cls_y)
    return (np.concatenate(balanced_X1),
            np.concatenate(balanced_X2),
            np.concatenate(balanced_X3),
            np.concatenate(balanced_y))

X_eeg, X_video, X_ecg, y = balance_classes(X_eeg, X_video, X_ecg, y, class_idx=1)
X_eeg, X_video, X_ecg, y = balance_classes(X_eeg, X_video, X_ecg, y, class_idx=2)

# ----------- SPLITTING -----------
X_eeg_train, X_eeg_test, X_video_train, X_video_test, X_ecg_train, X_ecg_test, y_train, y_test = \
    train_test_split(X_eeg, X_video, X_ecg, y, test_size=0.2, random_state=42)

num_valence_classes = int(np.max(y[:, 1])) + 1
num_arousal_classes = int(np.max(y[:, 2])) + 1

y_valence_train = to_categorical(y_train[:, 1], num_classes=num_valence_classes)
y_arousal_train = to_categorical(y_train[:, 2], num_classes=num_arousal_classes)
y_valence_test  = to_categorical(y_test[:, 1], num_classes=num_valence_classes)
y_arousal_test  = to_categorical(y_test[:, 2], num_classes=num_arousal_classes)

# ----------- VIDEO DATA FOR EFFICIENTNETB0 -----------
X_video_train_2d = X_video_train[:, 0, :, :][..., np.newaxis]  # [N, 64, 64, 1]
X_video_test_2d  = X_video_test[:, 0, :, :][..., np.newaxis]

# EfficientNet expects 3 channels and specific preprocessing
def efficientnet_preprocess(x):
    x = np.repeat(x, 3, axis=-1)  # (N, 64, 64, 3)
    return preprocess_input(x)

X_video_train_2d = efficientnet_preprocess(X_video_train_2d)
X_video_test_2d  = efficientnet_preprocess(X_video_test_2d)

# ----------- MODEL DEFINITION -----------

# ==== Video branch: EfficientNetB0 ====
video_input = Input(shape=(64, 64, 3), name="video_input")
efficientnet_base = EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_shape=(64, 64, 3),
    pooling='avg'
)
efficientnet_base.trainable = False  # Set True to fine-tune
x = efficientnet_base(video_input)
cnn_output = Dense(128, activation='relu')(x)

# ==== EEG branch ====
eeg_input = Input(shape=(5, 512), name="eeg_input")
lstm_eeg = LSTM(128, return_sequences=True)(eeg_input)
lstm_eeg = Dropout(0.2)(lstm_eeg)
lstm_eeg = LSTM(64)(lstm_eeg)
lstm_eeg_output = Dense(128, activation='relu')(lstm_eeg)

# ==== ECG branch ====
ecg_input = Input(shape=(2, 512), name="ecg_input")
lstm_ecg = LSTM(64, return_sequences=True)(ecg_input)
lstm_ecg = Dropout(0.2)(lstm_ecg)
lstm_ecg = LSTM(32)(lstm_ecg)
lstm_ecg_output = Dense(64, activation='relu')(lstm_ecg)

# ==== Combine modalities ====
combined = Concatenate()([cnn_output, lstm_eeg_output, lstm_ecg_output])
combined = Dense(256, activation='relu')(combined)
combined = Dropout(0.3)(combined)
combined = Dense(128, activation='relu')(combined)
combined = Dropout(0.2)(combined)

# ==== Output layers ====
valence_output = Dense(num_valence_classes, activation='softmax', name="valence_output")(combined)
arousal_output = Dense(num_arousal_classes, activation='softmax', name="arousal_output")(combined)

model = Model(
    inputs=[video_input, eeg_input, ecg_input],
    outputs=[valence_output, arousal_output]
)

model.compile(
    optimizer='adam',
    loss=['categorical_crossentropy', 'categorical_crossentropy'],
    metrics=['accuracy', 'accuracy']
)

model.summary()

# ----------- TRAINING -----------
history = model.fit(
    [X_video_train_2d, X_eeg_train, X_ecg_train],
    [y_valence_train, y_arousal_train],
    validation_data=(
        [X_video_test_2d, X_eeg_test, X_ecg_test],
        [y_valence_test, y_arousal_test]
    ),
    epochs=50,
    batch_size=128
)

# ----------- EVALUATION -----------
y_valence_pred, y_arousal_pred = model.predict([X_video_test_2d, X_eeg_test, X_ecg_test])
y_valence_pred_classes = np.argmax(y_valence_pred, axis=1)
y_arousal_pred_classes = np.argmax(y_arousal_pred, axis=1)
y_valence_true = np.argmax(y_valence_test, axis=1)
y_arousal_true = np.argmax(y_arousal_test, axis=1)

valence_accuracy = accuracy_score(y_valence_true, y_valence_pred_classes)
arousal_accuracy = accuracy_score(y_arousal_true, y_arousal_pred_classes)

print(f"Valence Accuracy: {valence_accuracy * 100:.2f}%")
print(f"Arousal Accuracy: {arousal_accuracy * 100:.2f}%")
# Out:
# Number of samples after duplication: 372
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ eeg_input           │ (None, 5, 512)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ecg_input           │ (None, 2, 512)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 5, 128)    │    328,192 │ eeg_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 2, 64)     │    147,712 │ ecg_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ video_input         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 5, 128)    │          0 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 2, 64)     │          0 │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ efficientnetb0      │ (None, 1280)      │  4,049,571 │ video_input[0][0] │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 64)        │     49,408 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ (None, 32)        │     12,416 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    163,968 │ efficientnetb0[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │      8,320 │ lstm_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      2,112 │ lstm_3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 320)       │          0 │ dense[0][0],      │
# │ (Concatenate)       │                   │            │ dense_1[0][0],    │
# │                     │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256)       │     82,176 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │     32,896 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ valence_output      │ (None, 10)        │      1,290 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ arousal_output      │ (None, 10)        │      1,290 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,879,351 (18.61 MB)
#  Trainable params: 829,780 (3.17 MB)
#  Non-trainable params: 4,049,571 (15.45 MB)
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - arousal_output_accuracy: 0.0918 - arousal_output_loss: 2.3176 - loss: 4.6028 - valence_output_accuracy: 0.1441 - valence_output_loss: 2.2805 - val_arousal_output_accuracy: 0.2284 - val_arousal_output_loss: 2.1845 - val_loss: 4.3705 - val_valence_output_accuracy: 0.2132 - val_valence_output_loss: 2.1797
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 702ms/step - arousal_output_accuracy: 0.1837 - arousal_output_loss: 2.1731 - loss: 4.2924 - valence_output_accuracy: 0.2247 - valence_output_loss: 2.1186 - val_arousal_output_accuracy: 0.2538 - val_arousal_output_loss: 2.0434 - val_loss: 4.0503 - val_valence_output_accuracy: 0.2386 - val_valence_output_loss: 2.0053
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 711ms/step - arousal_output_accuracy: 0.2340 - arousal_output_loss: 2.0789 - loss: 4.0760 - valence_output_accuracy: 0.2720 - valence_output_loss: 1.9928 - val_arousal_output_accuracy: 0.2690 - val_arousal_output_loss: 1.9461 - val_loss: 3.8730 - val_valence_output_accuracy: 0.3655 - val_valence_output_loss: 1.9388
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 894ms/step - arousal_output_accuracy: 0.3036 - arousal_output_loss: 1.9464 - loss: 3.8191 - valence_output_accuracy: 0.3373 - valence_output_loss: 1.8701 - val_arousal_output_accuracy: 0.3655 - val_arousal_output_loss: 1.8142 - val_loss: 3.6235 - val_valence_output_accuracy: 0.4010 - val_valence_output_loss: 1.8156
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 717ms/step - arousal_output_accuracy: 0.3610 - arousal_output_loss: 1.8093 - loss: 3.5874 - valence_output_accuracy: 0.3831 - valence_output_loss: 1.7661 - val_arousal_output_accuracy: 0.3807 - val_arousal_output_loss: 1.7250 - val_loss: 3.4546 - val_valence_output_accuracy: 0.4010 - val_valence_output_loss: 1.7458
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 910ms/step - arousal_output_accuracy: 0.4117 - arousal_output_loss: 1.7166 - loss: 3.3739 - valence_output_accuracy: 0.4175 - valence_output_loss: 1.6673 - val_arousal_output_accuracy: 0.3807 - val_arousal_output_loss: 1.6075 - val_loss: 3.1826 - val_valence_output_accuracy: 0.4162 - val_valence_output_loss: 1.5982
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 640ms/step - arousal_output_accuracy: 0.3758 - arousal_output_loss: 1.6843 - loss: 3.2756 - valence_output_accuracy: 0.4579 - valence_output_loss: 1.5809 - val_arousal_output_accuracy: 0.4518 - val_arousal_output_loss: 1.4996 - val_loss: 3.0334 - val_valence_output_accuracy: 0.4467 - val_valence_output_loss: 1.5565
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 891ms/step - arousal_output_accuracy: 0.4581 - arousal_output_loss: 1.5386 - loss: 2.9218 - valence_output_accuracy: 0.5352 - valence_output_loss: 1.3937 - val_arousal_output_accuracy: 0.4873 - val_arousal_output_loss: 1.3923 - val_loss: 2.7612 - val_valence_output_accuracy: 0.4924 - val_valence_output_loss: 1.4107
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 698ms/step - arousal_output_accuracy: 0.5200 - arousal_output_loss: 1.3759 - loss: 2.6949 - valence_output_accuracy: 0.5534 - valence_output_loss: 1.3061 - val_arousal_output_accuracy: 0.5330 - val_arousal_output_loss: 1.3009 - val_loss: 2.5875 - val_valence_output_accuracy: 0.5279 - val_valence_output_loss: 1.3287
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 722ms/step - arousal_output_accuracy: 0.5317 - arousal_output_loss: 1.2915 - loss: 2.5256 - valence_output_accuracy: 0.5813 - valence_output_loss: 1.2192 - val_arousal_output_accuracy: 0.5838 - val_arousal_output_loss: 1.2368 - val_loss: 2.5567 - val_valence_output_accuracy: 0.4772 - val_valence_output_loss: 1.3856
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 803ms/step - arousal_output_accuracy: 0.5698 - arousal_output_loss: 1.2361 - loss: 2.4062 - valence_output_accuracy: 0.5682 - valence_output_loss: 1.1577 - val_arousal_output_accuracy: 0.6193 - val_arousal_output_loss: 1.2077 - val_loss: 2.4748 - val_valence_output_accuracy: 0.4822 - val_valence_output_loss: 1.3457
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - arousal_output_accuracy: 0.5999 - arousal_output_loss: 1.1351 - loss: 2.2065 - valence_output_accuracy: 0.6232 - valence_output_loss: 1.0676 - val_arousal_output_accuracy: 0.6650 - val_arousal_output_loss: 1.1199 - val_loss: 2.2979 - val_valence_output_accuracy: 0.5939 - val_valence_output_loss: 1.2420
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 633ms/step - arousal_output_accuracy: 0.6519 - arousal_output_loss: 1.0341 - loss: 2.0262 - valence_output_accuracy: 0.6614 - valence_output_loss: 1.0031 - val_arousal_output_accuracy: 0.6396 - val_arousal_output_loss: 1.1318 - val_loss: 2.2726 - val_valence_output_accuracy: 0.6091 - val_valence_output_loss: 1.2112
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 916ms/step - arousal_output_accuracy: 0.6337 - arousal_output_loss: 0.9820 - loss: 1.9344 - valence_output_accuracy: 0.6759 - valence_output_loss: 0.9703 - val_arousal_output_accuracy: 0.6751 - val_arousal_output_loss: 0.9897 - val_loss: 2.0108 - val_valence_output_accuracy: 0.5990 - val_valence_output_loss: 1.1099
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 656ms/step - arousal_output_accuracy: 0.6958 - arousal_output_loss: 0.8919 - loss: 1.7721 - valence_output_accuracy: 0.6885 - valence_output_loss: 0.8764 - val_arousal_output_accuracy: 0.6954 - val_arousal_output_loss: 0.9876 - val_loss: 2.0292 - val_valence_output_accuracy: 0.6599 - val_valence_output_loss: 1.1434
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 924ms/step - arousal_output_accuracy: 0.7119 - arousal_output_loss: 0.8507 - loss: 1.6848 - valence_output_accuracy: 0.7000 - valence_output_loss: 0.8516 - val_arousal_output_accuracy: 0.7107 - val_arousal_output_loss: 0.8972 - val_loss: 1.8042 - val_valence_output_accuracy: 0.6802 - val_valence_output_loss: 0.9800
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 700ms/step - arousal_output_accuracy: 0.7327 - arousal_output_loss: 0.7606 - loss: 1.5658 - valence_output_accuracy: 0.7140 - valence_output_loss: 0.8146 - val_arousal_output_accuracy: 0.7614 - val_arousal_output_loss: 0.8183 - val_loss: 1.6551 - val_valence_output_accuracy: 0.7056 - val_valence_output_loss: 0.9341
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 753ms/step - arousal_output_accuracy: 0.7557 - arousal_output_loss: 0.7279 - loss: 1.4718 - valence_output_accuracy: 0.7515 - valence_output_loss: 0.7517 - val_arousal_output_accuracy: 0.8020 - val_arousal_output_loss: 0.7396 - val_loss: 1.5192 - val_valence_output_accuracy: 0.7360 - val_valence_output_loss: 0.8755
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - arousal_output_accuracy: 0.7631 - arousal_output_loss: 0.7128 - loss: 1.4043 - valence_output_accuracy: 0.7241 - valence_output_loss: 0.7230 - val_arousal_output_accuracy: 0.8173 - val_arousal_output_loss: 0.7080 - val_loss: 1.4026 - val_valence_output_accuracy: 0.7919 - val_valence_output_loss: 0.8077
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 712ms/step - arousal_output_accuracy: 0.7786 - arousal_output_loss: 0.6249 - loss: 1.2720 - valence_output_accuracy: 0.7804 - valence_output_loss: 0.6590 - val_arousal_output_accuracy: 0.7919 - val_arousal_output_loss: 0.7695 - val_loss: 1.5883 - val_valence_output_accuracy: 0.7056 - val_valence_output_loss: 0.9087
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 968ms/step - arousal_output_accuracy: 0.7689 - arousal_output_loss: 0.6705 - loss: 1.3033 - valence_output_accuracy: 0.7736 - valence_output_loss: 0.6350 - val_arousal_output_accuracy: 0.7766 - val_arousal_output_loss: 0.7293 - val_loss: 1.4762 - val_valence_output_accuracy: 0.7259 - val_valence_output_loss: 0.8517
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 716ms/step - arousal_output_accuracy: 0.8181 - arousal_output_loss: 0.5869 - loss: 1.2041 - valence_output_accuracy: 0.7596 - valence_output_loss: 0.6240 - val_arousal_output_accuracy: 0.8173 - val_arousal_output_loss: 0.6569 - val_loss: 1.3162 - val_valence_output_accuracy: 0.7665 - val_valence_output_loss: 0.7538
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 748ms/step - arousal_output_accuracy: 0.8012 - arousal_output_loss: 0.5657 - loss: 1.2035 - valence_output_accuracy: 0.7711 - valence_output_loss: 0.6299 - val_arousal_output_accuracy: 0.7868 - val_arousal_output_loss: 0.7279 - val_loss: 1.4228 - val_valence_output_accuracy: 0.7868 - val_valence_output_loss: 0.8205
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 722ms/step - arousal_output_accuracy: 0.8300 - arousal_output_loss: 0.5127 - loss: 1.0226 - valence_output_accuracy: 0.8123 - valence_output_loss: 0.5067 - val_arousal_output_accuracy: 0.8071 - val_arousal_output_loss: 0.6801 - val_loss: 1.2938 - val_valence_output_accuracy: 0.7919 - val_valence_output_loss: 0.7375
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - arousal_output_accuracy: 0.8146 - arousal_output_loss: 0.5161 - loss: 1.0152 - valence_output_accuracy: 0.8302 - valence_output_loss: 0.4902 - val_arousal_output_accuracy: 0.8376 - val_arousal_output_loss: 0.7307 - val_loss: 1.3462 - val_valence_output_accuracy: 0.8426 - val_valence_output_loss: 0.7611
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 636ms/step - arousal_output_accuracy: 0.8459 - arousal_output_loss: 0.4344 - loss: 0.9059 - valence_output_accuracy: 0.8213 - valence_output_loss: 0.4848 - val_arousal_output_accuracy: 0.8376 - val_arousal_output_loss: 0.8008 - val_loss: 1.3684 - val_valence_output_accuracy: 0.8477 - val_valence_output_loss: 0.7255
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 978ms/step - arousal_output_accuracy: 0.8527 - arousal_output_loss: 0.4671 - loss: 0.8853 - valence_output_accuracy: 0.8484 - valence_output_loss: 0.4301 - val_arousal_output_accuracy: 0.8579 - val_arousal_output_loss: 0.6377 - val_loss: 1.3003 - val_valence_output_accuracy: 0.8020 - val_valence_output_loss: 0.8002
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 711ms/step - arousal_output_accuracy: 0.8537 - arousal_output_loss: 0.4190 - loss: 0.8814 - valence_output_accuracy: 0.8236 - valence_output_loss: 0.4652 - val_arousal_output_accuracy: 0.8629 - val_arousal_output_loss: 0.5765 - val_loss: 1.1024 - val_valence_output_accuracy: 0.8426 - val_valence_output_loss: 0.6561
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 753ms/step - arousal_output_accuracy: 0.8742 - arousal_output_loss: 0.4194 - loss: 0.8388 - valence_output_accuracy: 0.8535 - valence_output_loss: 0.4174 - val_arousal_output_accuracy: 0.8782 - val_arousal_output_loss: 0.5850 - val_loss: 1.1020 - val_valence_output_accuracy: 0.8782 - val_valence_output_loss: 0.6454
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - arousal_output_accuracy: 0.8904 - arousal_output_loss: 0.3608 - loss: 0.7189 - valence_output_accuracy: 0.8784 - valence_output_loss: 0.3628 - val_arousal_output_accuracy: 0.8426 - val_arousal_output_loss: 0.7399 - val_loss: 1.3224 - val_valence_output_accuracy: 0.8528 - val_valence_output_loss: 0.7657
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 714ms/step - arousal_output_accuracy: 0.8583 - arousal_output_loss: 0.3855 - loss: 0.7688 - valence_output_accuracy: 0.8532 - valence_output_loss: 0.3776 - val_arousal_output_accuracy: 0.9188 - val_arousal_output_loss: 0.5948 - val_loss: 0.9403 - val_valence_output_accuracy: 0.9036 - val_valence_output_loss: 0.4905
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 964ms/step - arousal_output_accuracy: 0.9107 - arousal_output_loss: 0.2964 - loss: 0.5874 - valence_output_accuracy: 0.9002 - valence_output_loss: 0.3030 - val_arousal_output_accuracy: 0.8934 - val_arousal_output_loss: 0.5834 - val_loss: 1.0861 - val_valence_output_accuracy: 0.8883 - val_valence_output_loss: 0.6686
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 718ms/step - arousal_output_accuracy: 0.8955 - arousal_output_loss: 0.2910 - loss: 0.5595 - valence_output_accuracy: 0.9123 - valence_output_loss: 0.2648 - val_arousal_output_accuracy: 0.8832 - val_arousal_output_loss: 0.6027 - val_loss: 0.9562 - val_valence_output_accuracy: 0.9036 - val_valence_output_loss: 0.5185
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 855ms/step - arousal_output_accuracy: 0.9096 - arousal_output_loss: 0.2717 - loss: 0.5304 - valence_output_accuracy: 0.9221 - valence_output_loss: 0.2517 - val_arousal_output_accuracy: 0.8985 - val_arousal_output_loss: 0.6028 - val_loss: 1.0175 - val_valence_output_accuracy: 0.8985 - val_valence_output_loss: 0.5742
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 811ms/step - arousal_output_accuracy: 0.9106 - arousal_output_loss: 0.2751 - loss: 0.5662 - valence_output_accuracy: 0.8970 - valence_output_loss: 0.2811 - val_arousal_output_accuracy: 0.8832 - val_arousal_output_loss: 0.5848 - val_loss: 1.0261 - val_valence_output_accuracy: 0.8985 - val_valence_output_loss: 0.6112
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 652ms/step - arousal_output_accuracy: 0.9211 - arousal_output_loss: 0.2635 - loss: 0.4883 - valence_output_accuracy: 0.9243 - valence_output_loss: 0.2374 - val_arousal_output_accuracy: 0.9036 - val_arousal_output_loss: 0.6395 - val_loss: 1.0210 - val_valence_output_accuracy: 0.8985 - val_valence_output_loss: 0.5626
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 900ms/step - arousal_output_accuracy: 0.9252 - arousal_output_loss: 0.2238 - loss: 0.4264 - valence_output_accuracy: 0.9475 - valence_output_loss: 0.2026 - val_arousal_output_accuracy: 0.8883 - val_arousal_output_loss: 0.6335 - val_loss: 1.0326 - val_valence_output_accuracy: 0.9086 - val_valence_output_loss: 0.5711
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 675ms/step - arousal_output_accuracy: 0.9166 - arousal_output_loss: 0.2425 - loss: 0.4393 - valence_output_accuracy: 0.9355 - valence_output_loss: 0.1969 - val_arousal_output_accuracy: 0.9289 - val_arousal_output_loss: 0.5770 - val_loss: 0.9596 - val_valence_output_accuracy: 0.9239 - val_valence_output_loss: 0.5543
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 935ms/step - arousal_output_accuracy: 0.9180 - arousal_output_loss: 0.2182 - loss: 0.3860 - valence_output_accuracy: 0.9528 - valence_output_loss: 0.1624 - val_arousal_output_accuracy: 0.9086 - val_arousal_output_loss: 0.5912 - val_loss: 0.9008 - val_valence_output_accuracy: 0.9391 - val_valence_output_loss: 0.4724
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 729ms/step - arousal_output_accuracy: 0.9342 - arousal_output_loss: 0.2046 - loss: 0.3956 - valence_output_accuracy: 0.9302 - valence_output_loss: 0.1878 - val_arousal_output_accuracy: 0.9289 - val_arousal_output_loss: 0.5264 - val_loss: 0.9041 - val_valence_output_accuracy: 0.9188 - val_valence_output_loss: 0.5387
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 744ms/step - arousal_output_accuracy: 0.9428 - arousal_output_loss: 0.1642 - loss: 0.3100 - valence_output_accuracy: 0.9564 - valence_output_loss: 0.1398 - val_arousal_output_accuracy: 0.9289 - val_arousal_output_loss: 0.5846 - val_loss: 0.9214 - val_valence_output_accuracy: 0.9442 - val_valence_output_loss: 0.5224
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 896ms/step - arousal_output_accuracy: 0.9425 - arousal_output_loss: 0.1799 - loss: 0.3279 - valence_output_accuracy: 0.9568 - valence_output_loss: 0.1596 - val_arousal_output_accuracy: 0.9188 - val_arousal_output_loss: 0.6036 - val_loss: 0.9687 - val_valence_output_accuracy: 0.9289 - val_valence_output_loss: 0.5687
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 723ms/step - arousal_output_accuracy: 0.9364 - arousal_output_loss: 0.1874 - loss: 0.3331 - valence_output_accuracy: 0.9562 - valence_output_loss: 0.1379 - val_arousal_output_accuracy: 0.9188 - val_arousal_output_loss: 0.7821 - val_loss: 1.0819 - val_valence_output_accuracy: 0.9188 - val_valence_output_loss: 0.5237
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 912ms/step - arousal_output_accuracy: 0.9525 - arousal_output_loss: 0.1733 - loss: 0.3129 - valence_output_accuracy: 0.9559 - valence_output_loss: 0.1413 - val_arousal_output_accuracy: 0.8782 - val_arousal_output_loss: 0.5691 - val_loss: 0.9573 - val_valence_output_accuracy: 0.9137 - val_valence_output_loss: 0.5543
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 643ms/step - arousal_output_accuracy: 0.9350 - arousal_output_loss: 0.1921 - loss: 0.3310 - valence_output_accuracy: 0.9525 - valence_output_loss: 0.1342 - val_arousal_output_accuracy: 0.9340 - val_arousal_output_loss: 0.4961 - val_loss: 0.8428 - val_valence_output_accuracy: 0.9340 - val_valence_output_loss: 0.5150
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 719ms/step - arousal_output_accuracy: 0.9388 - arousal_output_loss: 0.1822 - loss: 0.3085 - valence_output_accuracy: 0.9605 - valence_output_loss: 0.1222 - val_arousal_output_accuracy: 0.9289 - val_arousal_output_loss: 0.6357 - val_loss: 0.9829 - val_valence_output_accuracy: 0.9340 - val_valence_output_loss: 0.5531
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 745ms/step - arousal_output_accuracy: 0.9575 - arousal_output_loss: 0.1454 - loss: 0.2896 - valence_output_accuracy: 0.9594 - valence_output_loss: 0.1371 - val_arousal_output_accuracy: 0.9340 - val_arousal_output_loss: 0.4926 - val_loss: 0.8714 - val_valence_output_accuracy: 0.9289 - val_valence_output_loss: 0.5587
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 877ms/step - arousal_output_accuracy: 0.9591 - arousal_output_loss: 0.1374 - loss: 0.2470 - valence_output_accuracy: 0.9713 - valence_output_loss: 0.1123 - val_arousal_output_accuracy: 0.9289 - val_arousal_output_loss: 0.5789 - val_loss: 1.0077 - val_valence_output_accuracy: 0.9391 - val_valence_output_loss: 0.6506
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 701ms/step - arousal_output_accuracy: 0.9635 - arousal_output_loss: 0.1122 - loss: 0.2518 - valence_output_accuracy: 0.9522 - valence_output_loss: 0.1341 - val_arousal_output_accuracy: 0.9137 - val_arousal_output_loss: 0.6602 - val_loss: 1.0053 - val_valence_output_accuracy: 0.9239 - val_valence_output_loss: 0.5537
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 648ms/step - arousal_output_accuracy: 0.9590 - arousal_output_loss: 0.1379 - loss: 0.2351 - valence_output_accuracy: 0.9740 - valence_output_loss: 0.0970 - val_arousal_output_accuracy: 0.9340 - val_arousal_output_loss: 0.6570 - val_loss: 0.9395 - val_valence_output_accuracy: 0.9391 - val_valence_output_loss: 0.4952
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 653ms/step
# Valence Accuracy: 93.91%
# Arousal Accuracy: 93.40%

# %% [markdown]
# **Without duplicate data**

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, LSTM, Dropout, Concatenate, BatchNormalization, Lambda
)
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.utils import resample
from tensorflow.keras.utils import to_categorical

# ----------- DATA LOADING & DUPLICATION -----------
data_path = '/content/drive/MyDrive/dataset/preprocessed-data/mahnob_HCI_preprocessed_all.npy'
data = np.load(data_path, allow_pickle=True)

# ----------- FEATURES AND LABELS -----------
X_eeg   = np.array([entry['eeg_data']  for entry in data])
X_video = np.array([entry['video_data'] for entry in data]) # (N, 32, 64, 64)
X_ecg   = np.array([entry['ecg_data']  for entry in data])
y       = np.array([entry['labels']    for entry in data])
print(f"Number of samples after duplication: {len(data)}")

# Pad video data if needed
if X_video.shape[1:] != (32, 64, 64):
    padded_video = []
    for video in X_video:
        pad_shape = [
            (0, max(0, 32 - video.shape[0])),
            (0, max(0, 64 - video.shape[1])),
            (0, max(0, 64 - video.shape[2]))
        ]
        padded_video.append(np.pad(video, pad_shape, mode='constant'))
    X_video = np.array(padded_video)

# ----------- CLASS BALANCING -----------
def balance_classes(X1, X2, X3, y, class_idx):
    labels = y[:, class_idx]
    unique_classes, class_counts = np.unique(labels, return_counts=True)
    max_count = np.max(class_counts)

    balanced_X1, balanced_X2, balanced_X3, balanced_y = [], [], [], []
    for cls in unique_classes:
        cls_mask = labels == cls
        cls_X1, cls_X2, cls_X3, cls_y = X1[cls_mask], X2[cls_mask], X3[cls_mask], y[cls_mask]

        if len(cls_y) < max_count:
            X1_oversampled, X2_oversampled, X3_oversampled, y_oversampled = resample(
                cls_X1, cls_X2, cls_X3, cls_y, replace=True,
                n_samples=max_count - len(cls_y), random_state=42)
            cls_X1 = np.concatenate([cls_X1, X1_oversampled])
            cls_X2 = np.concatenate([cls_X2, X2_oversampled])
            cls_X3 = np.concatenate([cls_X3, X3_oversampled])
            cls_y  = np.concatenate([cls_y,  y_oversampled])
        balanced_X1.append(cls_X1)
        balanced_X2.append(cls_X2)
        balanced_X3.append(cls_X3)
        balanced_y.append(cls_y)
    return (np.concatenate(balanced_X1),
            np.concatenate(balanced_X2),
            np.concatenate(balanced_X3),
            np.concatenate(balanced_y))

X_eeg, X_video, X_ecg, y = balance_classes(X_eeg, X_video, X_ecg, y, class_idx=1)
X_eeg, X_video, X_ecg, y = balance_classes(X_eeg, X_video, X_ecg, y, class_idx=2)

# ----------- SPLITTING -----------
X_eeg_train, X_eeg_test, X_video_train, X_video_test, X_ecg_train, X_ecg_test, y_train, y_test = \
    train_test_split(X_eeg, X_video, X_ecg, y, test_size=0.2, random_state=42)

num_valence_classes = int(np.max(y[:, 1])) + 1
num_arousal_classes = int(np.max(y[:, 2])) + 1

y_valence_train = to_categorical(y_train[:, 1], num_classes=num_valence_classes)
y_arousal_train = to_categorical(y_train[:, 2], num_classes=num_arousal_classes)
y_valence_test  = to_categorical(y_test[:, 1], num_classes=num_valence_classes)
y_arousal_test  = to_categorical(y_test[:, 2], num_classes=num_arousal_classes)

# ----------- VIDEO DATA FOR EFFICIENTNETB0 -----------
X_video_train_2d = X_video_train[:, 0, :, :][..., np.newaxis]  # [N, 64, 64, 1]
X_video_test_2d  = X_video_test[:, 0, :, :][..., np.newaxis]

# EfficientNet expects 3 channels and specific preprocessing
def efficientnet_preprocess(x):
    x = np.repeat(x, 3, axis=-1)  # (N, 64, 64, 3)
    return preprocess_input(x)

X_video_train_2d = efficientnet_preprocess(X_video_train_2d)
X_video_test_2d  = efficientnet_preprocess(X_video_test_2d)

# ----------- MODEL DEFINITION -----------

# ==== Video branch: EfficientNetB0 ====
video_input = Input(shape=(64, 64, 3), name="video_input")
efficientnet_base = EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_shape=(64, 64, 3),
    pooling='avg'
)
efficientnet_base.trainable = False  # Set True to fine-tune
x = efficientnet_base(video_input)
cnn_output = Dense(128, activation='relu')(x)

# ==== EEG branch ====
eeg_input = Input(shape=(5, 512), name="eeg_input")
lstm_eeg = LSTM(128, return_sequences=True)(eeg_input)
lstm_eeg = Dropout(0.2)(lstm_eeg)
lstm_eeg = LSTM(64)(lstm_eeg)
lstm_eeg_output = Dense(128, activation='relu')(lstm_eeg)

# ==== ECG branch ====
ecg_input = Input(shape=(2, 512), name="ecg_input")
lstm_ecg = LSTM(64, return_sequences=True)(ecg_input)
lstm_ecg = Dropout(0.2)(lstm_ecg)
lstm_ecg = LSTM(32)(lstm_ecg)
lstm_ecg_output = Dense(64, activation='relu')(lstm_ecg)

# ==== Combine modalities ====
combined = Concatenate()([cnn_output, lstm_eeg_output, lstm_ecg_output])
combined = Dense(256, activation='relu')(combined)
combined = Dropout(0.3)(combined)
combined = Dense(128, activation='relu')(combined)
combined = Dropout(0.2)(combined)

# ==== Output layers ====
valence_output = Dense(num_valence_classes, activation='softmax', name="valence_output")(combined)
arousal_output = Dense(num_arousal_classes, activation='softmax', name="arousal_output")(combined)

model = Model(
    inputs=[video_input, eeg_input, ecg_input],
    outputs=[valence_output, arousal_output]
)

model.compile(
    optimizer='adam',
    loss=['categorical_crossentropy', 'categorical_crossentropy'],
    metrics=['accuracy', 'accuracy']
)

model.summary()

# ----------- TRAINING -----------
history = model.fit(
    [X_video_train_2d, X_eeg_train, X_ecg_train],
    [y_valence_train, y_arousal_train],
    validation_data=(
        [X_video_test_2d, X_eeg_test, X_ecg_test],
        [y_valence_test, y_arousal_test]
    ),
    epochs=50,
    batch_size=128
)

# ----------- EVALUATION -----------
y_valence_pred, y_arousal_pred = model.predict([X_video_test_2d, X_eeg_test, X_ecg_test])
y_valence_pred_classes = np.argmax(y_valence_pred, axis=1)
y_arousal_pred_classes = np.argmax(y_arousal_pred, axis=1)
y_valence_true = np.argmax(y_valence_test, axis=1)
y_arousal_true = np.argmax(y_arousal_test, axis=1)

valence_accuracy = accuracy_score(y_valence_true, y_valence_pred_classes)
arousal_accuracy = accuracy_score(y_arousal_true, y_arousal_pred_classes)

print(f"Valence Accuracy: {valence_accuracy * 100:.2f}%")
print(f"Arousal Accuracy: {arousal_accuracy * 100:.2f}%")
# Out:
# Number of samples after duplication: 186
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ eeg_input           │ (None, 5, 512)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ecg_input           │ (None, 2, 512)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 5, 128)    │    328,192 │ eeg_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 2, 64)     │    147,712 │ ecg_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ video_input         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 5, 128)    │          0 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 2, 64)     │          0 │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ efficientnetb0      │ (None, 1280)      │  4,049,571 │ video_input[0][0] │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 64)        │     49,408 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ (None, 32)        │     12,416 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    163,968 │ efficientnetb0[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │      8,320 │ lstm_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      2,112 │ lstm_3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 320)       │          0 │ dense[0][0],      │
# │ (Concatenate)       │                   │            │ dense_1[0][0],    │
# │                     │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256)       │     82,176 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │     32,896 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ valence_output      │ (None, 10)        │      1,290 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ arousal_output      │ (None, 10)        │      1,290 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,879,351 (18.61 MB)
#  Trainable params: 829,780 (3.17 MB)
#  Non-trainable params: 4,049,571 (15.45 MB)
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 30s 4s/step - arousal_output_accuracy: 0.1275 - arousal_output_loss: 2.3194 - loss: 4.6091 - valence_output_accuracy: 0.1287 - valence_output_loss: 2.2890 - val_arousal_output_accuracy: 0.1915 - val_arousal_output_loss: 2.2324 - val_loss: 4.5147 - val_valence_output_accuracy: 0.1596 - val_valence_output_loss: 2.2822
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 937ms/step - arousal_output_accuracy: 0.1599 - arousal_output_loss: 2.2299 - loss: 4.4315 - valence_output_accuracy: 0.1918 - valence_output_loss: 2.2006 - val_arousal_output_accuracy: 0.3298 - val_arousal_output_loss: 2.1582 - val_loss: 4.4114 - val_valence_output_accuracy: 0.1915 - val_valence_output_loss: 2.2532
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 812ms/step - arousal_output_accuracy: 0.1858 - arousal_output_loss: 2.1420 - loss: 4.3025 - valence_output_accuracy: 0.2085 - valence_output_loss: 2.1601 - val_arousal_output_accuracy: 0.2447 - val_arousal_output_loss: 2.1230 - val_loss: 4.3150 - val_valence_output_accuracy: 0.2128 - val_valence_output_loss: 2.1920
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 906ms/step - arousal_output_accuracy: 0.2331 - arousal_output_loss: 2.0972 - loss: 4.1502 - valence_output_accuracy: 0.2508 - valence_output_loss: 2.0521 - val_arousal_output_accuracy: 0.1596 - val_arousal_output_loss: 2.1097 - val_loss: 4.1750 - val_valence_output_accuracy: 0.2766 - val_valence_output_loss: 2.0653
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - arousal_output_accuracy: 0.2905 - arousal_output_loss: 2.0465 - loss: 4.0544 - valence_output_accuracy: 0.2755 - valence_output_loss: 2.0085 - val_arousal_output_accuracy: 0.2660 - val_arousal_output_loss: 2.0731 - val_loss: 4.0260 - val_valence_output_accuracy: 0.3830 - val_valence_output_loss: 1.9530
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 829ms/step - arousal_output_accuracy: 0.3196 - arousal_output_loss: 1.9051 - loss: 3.7858 - valence_output_accuracy: 0.3520 - valence_output_loss: 1.8808 - val_arousal_output_accuracy: 0.2766 - val_arousal_output_loss: 1.9939 - val_loss: 3.8663 - val_valence_output_accuracy: 0.4149 - val_valence_output_loss: 1.8724
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 915ms/step - arousal_output_accuracy: 0.2953 - arousal_output_loss: 1.9184 - loss: 3.7797 - valence_output_accuracy: 0.3356 - valence_output_loss: 1.8622 - val_arousal_output_accuracy: 0.3191 - val_arousal_output_loss: 1.9399 - val_loss: 3.7153 - val_valence_output_accuracy: 0.4255 - val_valence_output_loss: 1.7754
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 903ms/step - arousal_output_accuracy: 0.3219 - arousal_output_loss: 1.8524 - loss: 3.6426 - valence_output_accuracy: 0.3463 - valence_output_loss: 1.7923 - val_arousal_output_accuracy: 0.2979 - val_arousal_output_loss: 1.9016 - val_loss: 3.5902 - val_valence_output_accuracy: 0.4362 - val_valence_output_loss: 1.6886
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - arousal_output_accuracy: 0.3695 - arousal_output_loss: 1.7995 - loss: 3.5267 - valence_output_accuracy: 0.4046 - valence_output_loss: 1.7263 - val_arousal_output_accuracy: 0.3298 - val_arousal_output_loss: 1.8415 - val_loss: 3.4699 - val_valence_output_accuracy: 0.4894 - val_valence_output_loss: 1.6285
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 917ms/step - arousal_output_accuracy: 0.3884 - arousal_output_loss: 1.7750 - loss: 3.4381 - valence_output_accuracy: 0.4163 - valence_output_loss: 1.6617 - val_arousal_output_accuracy: 0.3830 - val_arousal_output_loss: 1.7606 - val_loss: 3.3244 - val_valence_output_accuracy: 0.4894 - val_valence_output_loss: 1.5638
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 916ms/step - arousal_output_accuracy: 0.4094 - arousal_output_loss: 1.7346 - loss: 3.3293 - valence_output_accuracy: 0.4620 - valence_output_loss: 1.5960 - val_arousal_output_accuracy: 0.4574 - val_arousal_output_loss: 1.6834 - val_loss: 3.1668 - val_valence_output_accuracy: 0.4894 - val_valence_output_loss: 1.4834
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 844ms/step - arousal_output_accuracy: 0.4689 - arousal_output_loss: 1.5737 - loss: 3.0658 - valence_output_accuracy: 0.4256 - valence_output_loss: 1.4932 - val_arousal_output_accuracy: 0.4149 - val_arousal_output_loss: 1.6190 - val_loss: 3.0580 - val_valence_output_accuracy: 0.5106 - val_valence_output_loss: 1.4389
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - arousal_output_accuracy: 0.4409 - arousal_output_loss: 1.5428 - loss: 3.0021 - valence_output_accuracy: 0.4668 - valence_output_loss: 1.4578 - val_arousal_output_accuracy: 0.3936 - val_arousal_output_loss: 1.5795 - val_loss: 3.0041 - val_valence_output_accuracy: 0.5532 - val_valence_output_loss: 1.4245
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 799ms/step - arousal_output_accuracy: 0.4753 - arousal_output_loss: 1.5061 - loss: 2.8799 - valence_output_accuracy: 0.5101 - valence_output_loss: 1.3728 - val_arousal_output_accuracy: 0.4681 - val_arousal_output_loss: 1.4991 - val_loss: 2.8574 - val_valence_output_accuracy: 0.5851 - val_valence_output_loss: 1.3583
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 793ms/step - arousal_output_accuracy: 0.5189 - arousal_output_loss: 1.4078 - loss: 2.7321 - valence_output_accuracy: 0.5446 - valence_output_loss: 1.3241 - val_arousal_output_accuracy: 0.4894 - val_arousal_output_loss: 1.4666 - val_loss: 2.7798 - val_valence_output_accuracy: 0.5532 - val_valence_output_loss: 1.3131
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 841ms/step - arousal_output_accuracy: 0.5565 - arousal_output_loss: 1.3115 - loss: 2.5816 - valence_output_accuracy: 0.5593 - valence_output_loss: 1.2681 - val_arousal_output_accuracy: 0.4681 - val_arousal_output_loss: 1.4258 - val_loss: 2.7652 - val_valence_output_accuracy: 0.6170 - val_valence_output_loss: 1.3395
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 916ms/step - arousal_output_accuracy: 0.5593 - arousal_output_loss: 1.2782 - loss: 2.4197 - valence_output_accuracy: 0.5849 - valence_output_loss: 1.1442 - val_arousal_output_accuracy: 0.5000 - val_arousal_output_loss: 1.2885 - val_loss: 2.5377 - val_valence_output_accuracy: 0.5532 - val_valence_output_loss: 1.2492
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - arousal_output_accuracy: 0.6205 - arousal_output_loss: 1.1344 - loss: 2.2331 - valence_output_accuracy: 0.6464 - valence_output_loss: 1.0988 - val_arousal_output_accuracy: 0.5745 - val_arousal_output_loss: 1.2616 - val_loss: 2.4753 - val_valence_output_accuracy: 0.6277 - val_valence_output_loss: 1.2136
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 813ms/step - arousal_output_accuracy: 0.6166 - arousal_output_loss: 1.1130 - loss: 2.1479 - valence_output_accuracy: 0.6519 - valence_output_loss: 1.0346 - val_arousal_output_accuracy: 0.6277 - val_arousal_output_loss: 1.1815 - val_loss: 2.2723 - val_valence_output_accuracy: 0.6489 - val_valence_output_loss: 1.0908
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 822ms/step - arousal_output_accuracy: 0.6062 - arousal_output_loss: 1.1256 - loss: 2.0818 - valence_output_accuracy: 0.6797 - valence_output_loss: 0.9561 - val_arousal_output_accuracy: 0.5745 - val_arousal_output_loss: 1.1092 - val_loss: 2.2510 - val_valence_output_accuracy: 0.6489 - val_valence_output_loss: 1.1418
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 828ms/step - arousal_output_accuracy: 0.6969 - arousal_output_loss: 0.9549 - loss: 1.8309 - valence_output_accuracy: 0.7024 - valence_output_loss: 0.8763 - val_arousal_output_accuracy: 0.6596 - val_arousal_output_loss: 1.1151 - val_loss: 2.1560 - val_valence_output_accuracy: 0.7128 - val_valence_output_loss: 1.0409
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - arousal_output_accuracy: 0.6757 - arousal_output_loss: 0.9682 - loss: 1.8088 - valence_output_accuracy: 0.7233 - valence_output_loss: 0.8378 - val_arousal_output_accuracy: 0.6489 - val_arousal_output_loss: 1.0110 - val_loss: 2.0347 - val_valence_output_accuracy: 0.6596 - val_valence_output_loss: 1.0237
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 816ms/step - arousal_output_accuracy: 0.7516 - arousal_output_loss: 0.8247 - loss: 1.6348 - valence_output_accuracy: 0.7447 - valence_output_loss: 0.8083 - val_arousal_output_accuracy: 0.6702 - val_arousal_output_loss: 0.9613 - val_loss: 2.1670 - val_valence_output_accuracy: 0.6277 - val_valence_output_loss: 1.2056
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 833ms/step - arousal_output_accuracy: 0.7476 - arousal_output_loss: 0.7571 - loss: 1.4846 - valence_output_accuracy: 0.7481 - valence_output_loss: 0.7286 - val_arousal_output_accuracy: 0.7553 - val_arousal_output_loss: 0.8628 - val_loss: 1.8544 - val_valence_output_accuracy: 0.7340 - val_valence_output_loss: 0.9916
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 813ms/step - arousal_output_accuracy: 0.7559 - arousal_output_loss: 0.7418 - loss: 1.4475 - valence_output_accuracy: 0.7908 - valence_output_loss: 0.7061 - val_arousal_output_accuracy: 0.7128 - val_arousal_output_loss: 0.9311 - val_loss: 1.9891 - val_valence_output_accuracy: 0.6809 - val_valence_output_loss: 1.0580
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - arousal_output_accuracy: 0.7607 - arousal_output_loss: 0.7317 - loss: 1.4489 - valence_output_accuracy: 0.7644 - valence_output_loss: 0.7132 - val_arousal_output_accuracy: 0.7128 - val_arousal_output_loss: 0.8186 - val_loss: 1.7283 - val_valence_output_accuracy: 0.7234 - val_valence_output_loss: 0.9097
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 926ms/step - arousal_output_accuracy: 0.7956 - arousal_output_loss: 0.6755 - loss: 1.3302 - valence_output_accuracy: 0.7732 - valence_output_loss: 0.6526 - val_arousal_output_accuracy: 0.7553 - val_arousal_output_loss: 0.8290 - val_loss: 1.7686 - val_valence_output_accuracy: 0.7553 - val_valence_output_loss: 0.9396
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 818ms/step - arousal_output_accuracy: 0.7895 - arousal_output_loss: 0.6320 - loss: 1.1915 - valence_output_accuracy: 0.8209 - valence_output_loss: 0.5588 - val_arousal_output_accuracy: 0.7766 - val_arousal_output_loss: 0.7326 - val_loss: 1.6994 - val_valence_output_accuracy: 0.7447 - val_valence_output_loss: 0.9668
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 854ms/step - arousal_output_accuracy: 0.8330 - arousal_output_loss: 0.5466 - loss: 1.0674 - valence_output_accuracy: 0.8260 - valence_output_loss: 0.5203 - val_arousal_output_accuracy: 0.7766 - val_arousal_output_loss: 0.7616 - val_loss: 1.7118 - val_valence_output_accuracy: 0.7660 - val_valence_output_loss: 0.9503
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 824ms/step - arousal_output_accuracy: 0.8196 - arousal_output_loss: 0.5196 - loss: 0.9928 - valence_output_accuracy: 0.8381 - valence_output_loss: 0.4743 - val_arousal_output_accuracy: 0.7872 - val_arousal_output_loss: 0.7421 - val_loss: 1.8675 - val_valence_output_accuracy: 0.7447 - val_valence_output_loss: 1.1254
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - arousal_output_accuracy: 0.8584 - arousal_output_loss: 0.5266 - loss: 1.0237 - valence_output_accuracy: 0.8369 - valence_output_loss: 0.4972 - val_arousal_output_accuracy: 0.7872 - val_arousal_output_loss: 0.7898 - val_loss: 1.7549 - val_valence_output_accuracy: 0.7660 - val_valence_output_loss: 0.9651
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 938ms/step - arousal_output_accuracy: 0.8399 - arousal_output_loss: 0.4729 - loss: 0.8705 - valence_output_accuracy: 0.8584 - valence_output_loss: 0.3983 - val_arousal_output_accuracy: 0.7766 - val_arousal_output_loss: 0.7976 - val_loss: 1.7748 - val_valence_output_accuracy: 0.7660 - val_valence_output_loss: 0.9772
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 928ms/step - arousal_output_accuracy: 0.8212 - arousal_output_loss: 0.4853 - loss: 0.9206 - valence_output_accuracy: 0.8519 - valence_output_loss: 0.4351 - val_arousal_output_accuracy: 0.7872 - val_arousal_output_loss: 0.6993 - val_loss: 1.6551 - val_valence_output_accuracy: 0.7553 - val_valence_output_loss: 0.9558
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 908ms/step - arousal_output_accuracy: 0.8980 - arousal_output_loss: 0.3951 - loss: 0.8155 - valence_output_accuracy: 0.8529 - valence_output_loss: 0.4208 - val_arousal_output_accuracy: 0.8085 - val_arousal_output_loss: 0.7539 - val_loss: 1.6265 - val_valence_output_accuracy: 0.7553 - val_valence_output_loss: 0.8726
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - arousal_output_accuracy: 0.8342 - arousal_output_loss: 0.4557 - loss: 0.8037 - valence_output_accuracy: 0.8981 - valence_output_loss: 0.3469 - val_arousal_output_accuracy: 0.7872 - val_arousal_output_loss: 0.8644 - val_loss: 1.9485 - val_valence_output_accuracy: 0.7234 - val_valence_output_loss: 1.0841
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 795ms/step - arousal_output_accuracy: 0.8766 - arousal_output_loss: 0.4019 - loss: 0.7493 - valence_output_accuracy: 0.8937 - valence_output_loss: 0.3482 - val_arousal_output_accuracy: 0.7979 - val_arousal_output_loss: 0.7192 - val_loss: 1.6246 - val_valence_output_accuracy: 0.7553 - val_valence_output_loss: 0.9054
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 837ms/step - arousal_output_accuracy: 0.8819 - arousal_output_loss: 0.4076 - loss: 0.7407 - valence_output_accuracy: 0.9173 - valence_output_loss: 0.3350 - val_arousal_output_accuracy: 0.8191 - val_arousal_output_loss: 0.7704 - val_loss: 1.7630 - val_valence_output_accuracy: 0.7553 - val_valence_output_loss: 0.9926
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 837ms/step - arousal_output_accuracy: 0.8760 - arousal_output_loss: 0.3545 - loss: 0.6380 - valence_output_accuracy: 0.9124 - valence_output_loss: 0.2856 - val_arousal_output_accuracy: 0.7872 - val_arousal_output_loss: 0.7917 - val_loss: 1.7017 - val_valence_output_accuracy: 0.7766 - val_valence_output_loss: 0.9100
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 950ms/step - arousal_output_accuracy: 0.8876 - arousal_output_loss: 0.3527 - loss: 0.6530 - valence_output_accuracy: 0.9086 - valence_output_loss: 0.2998 - val_arousal_output_accuracy: 0.8511 - val_arousal_output_loss: 0.6659 - val_loss: 1.5943 - val_valence_output_accuracy: 0.7979 - val_valence_output_loss: 0.9284
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 808ms/step - arousal_output_accuracy: 0.9034 - arousal_output_loss: 0.3337 - loss: 0.5816 - valence_output_accuracy: 0.9102 - valence_output_loss: 0.2486 - val_arousal_output_accuracy: 0.8085 - val_arousal_output_loss: 0.8578 - val_loss: 1.8693 - val_valence_output_accuracy: 0.7553 - val_valence_output_loss: 1.0115
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 825ms/step - arousal_output_accuracy: 0.9004 - arousal_output_loss: 0.3544 - loss: 0.6370 - valence_output_accuracy: 0.9146 - valence_output_loss: 0.2831 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.7213 - val_loss: 1.7468 - val_valence_output_accuracy: 0.7979 - val_valence_output_loss: 1.0254
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 918ms/step - arousal_output_accuracy: 0.9218 - arousal_output_loss: 0.2782 - loss: 0.5079 - valence_output_accuracy: 0.9302 - valence_output_loss: 0.2288 - val_arousal_output_accuracy: 0.7872 - val_arousal_output_loss: 0.7854 - val_loss: 1.8775 - val_valence_output_accuracy: 0.7660 - val_valence_output_loss: 1.0921
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 906ms/step - arousal_output_accuracy: 0.9257 - arousal_output_loss: 0.2667 - loss: 0.5082 - valence_output_accuracy: 0.9258 - valence_output_loss: 0.2413 - val_arousal_output_accuracy: 0.8191 - val_arousal_output_loss: 0.7334 - val_loss: 1.8223 - val_valence_output_accuracy: 0.7766 - val_valence_output_loss: 1.0889
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - arousal_output_accuracy: 0.9300 - arousal_output_loss: 0.2589 - loss: 0.4694 - valence_output_accuracy: 0.9166 - valence_output_loss: 0.2115 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.8420 - val_loss: 1.9225 - val_valence_output_accuracy: 0.8085 - val_valence_output_loss: 1.0805
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 922ms/step - arousal_output_accuracy: 0.9175 - arousal_output_loss: 0.2242 - loss: 0.4383 - valence_output_accuracy: 0.9446 - valence_output_loss: 0.2137 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.7622 - val_loss: 1.8380 - val_valence_output_accuracy: 0.7660 - val_valence_output_loss: 1.0759
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 913ms/step - arousal_output_accuracy: 0.9284 - arousal_output_loss: 0.2411 - loss: 0.4581 - valence_output_accuracy: 0.9360 - valence_output_loss: 0.2168 - val_arousal_output_accuracy: 0.7979 - val_arousal_output_loss: 0.8105 - val_loss: 1.8594 - val_valence_output_accuracy: 0.7766 - val_valence_output_loss: 1.0489
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 921ms/step - arousal_output_accuracy: 0.9084 - arousal_output_loss: 0.2587 - loss: 0.4746 - valence_output_accuracy: 0.9292 - valence_output_loss: 0.2151 - val_arousal_output_accuracy: 0.8191 - val_arousal_output_loss: 0.9497 - val_loss: 2.0801 - val_valence_output_accuracy: 0.7447 - val_valence_output_loss: 1.1304
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - arousal_output_accuracy: 0.9347 - arousal_output_loss: 0.2196 - loss: 0.4395 - valence_output_accuracy: 0.9314 - valence_output_loss: 0.2201 - val_arousal_output_accuracy: 0.8298 - val_arousal_output_loss: 0.8338 - val_loss: 1.8853 - val_valence_output_accuracy: 0.8085 - val_valence_output_loss: 1.0516
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 844ms/step - arousal_output_accuracy: 0.9187 - arousal_output_loss: 0.2205 - loss: 0.3832 - valence_output_accuracy: 0.9548 - valence_output_loss: 0.1619 - val_arousal_output_accuracy: 0.8191 - val_arousal_output_loss: 0.8514 - val_loss: 2.0626 - val_valence_output_accuracy: 0.7766 - val_valence_output_loss: 1.2111
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 937ms/step - arousal_output_accuracy: 0.9463 - arousal_output_loss: 0.2072 - loss: 0.3846 - valence_output_accuracy: 0.9403 - valence_output_loss: 0.1761 - val_arousal_output_accuracy: 0.8191 - val_arousal_output_loss: 0.8471 - val_loss: 2.0207 - val_valence_output_accuracy: 0.7660 - val_valence_output_loss: 1.1735
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step
# Valence Accuracy: 76.60%
# Arousal Accuracy: 81.91%
