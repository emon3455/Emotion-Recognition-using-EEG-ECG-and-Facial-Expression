# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **With Duplicate**

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv3D, MaxPooling3D, Flatten, Dense, LSTM, Dropout,
                                   Concatenate, BatchNormalization, ZeroPadding3D)
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils import resample
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load and duplicate dataset
data_path = '/content/drive/MyDrive/dataset/preprocessed-data/mahnob_HCI_preprocessed_all.npy'
data = np.load(data_path, allow_pickle=True)

def duplicate_dataset(data, num_duplicates):
    duplicated_data = data.tolist()
    for _ in range(num_duplicates):
        duplicated_data.extend(data.tolist())
    return np.array(duplicated_data)

# Duplicate dataset
num_duplicates = 2
data = duplicate_dataset(data, num_duplicates)

# Extract features and labels
X_eeg = np.array([entry['eeg_data'] for entry in data])
X_video = np.array([entry['video_data'] for entry in data])
X_ecg = np.array([entry['ecg_data'] for entry in data])
y = np.array([entry['labels'] for entry in data])

print(f"Number of samples after duplication: {len(data)}")

# Pad video data if needed
if X_video.shape[1:] != (32, 64, 64):
    padded_video = []
    for video in X_video:
        pad_shape = [
            (0, max(0, 32 - video.shape[0])),
            (0, max(0, 64 - video.shape[1])),
            (0, max(0, 64 - video.shape[2]))
        ]
        padded_video.append(np.pad(video, pad_shape, mode='constant'))
    X_video = np.array(padded_video)

# Modified balance_classes function for three modalities
def balance_classes(X1, X2, X3, y, class_idx):
    labels = y[:, class_idx]
    unique_classes, class_counts = np.unique(labels, return_counts=True)
    max_count = np.max(class_counts)

    balanced_X1, balanced_X2, balanced_X3, balanced_y = [], [], [], []
    for cls in unique_classes:
        cls_mask = labels == cls
        cls_X1, cls_X2, cls_X3, cls_y = X1[cls_mask], X2[cls_mask], X3[cls_mask], y[cls_mask]

        if len(cls_y) < max_count:
            X1_oversampled, X2_oversampled, X3_oversampled, y_oversampled = resample(
                cls_X1, cls_X2, cls_X3, cls_y,
                replace=True,
                n_samples=max_count - len(cls_y),
                random_state=42
            )
            cls_X1 = np.concatenate([cls_X1, X1_oversampled])
            cls_X2 = np.concatenate([cls_X2, X2_oversampled])
            cls_X3 = np.concatenate([cls_X3, X3_oversampled])
            cls_y = np.concatenate([cls_y, y_oversampled])

        balanced_X1.append(cls_X1)
        balanced_X2.append(cls_X2)
        balanced_X3.append(cls_X3)
        balanced_y.append(cls_y)

    return (np.concatenate(balanced_X1),
            np.concatenate(balanced_X2),
            np.concatenate(balanced_X3),
            np.concatenate(balanced_y))

# Balance classes
X_eeg, X_video, X_ecg, y = balance_classes(X_eeg, X_video, X_ecg, y, class_idx=1)
X_eeg, X_video, X_ecg, y = balance_classes(X_eeg, X_video, X_ecg, y, class_idx=2)

# Split data
X_eeg_train, X_eeg_test, X_video_train, X_video_test, X_ecg_train, X_ecg_test, y_train, y_test = train_test_split(
    X_eeg, X_video, X_ecg, y, test_size=0.2, random_state=42
)

# Prepare labels
num_valence_classes = int(np.max(y[:, 1])) + 1
num_arousal_classes = int(np.max(y[:, 2])) + 1

y_valence_train = to_categorical(y_train[:, 1], num_classes=num_valence_classes)
y_arousal_train = to_categorical(y_train[:, 2], num_classes=num_arousal_classes)
y_valence_test = to_categorical(y_test[:, 1], num_classes=num_valence_classes)
y_arousal_test = to_categorical(y_test[:, 2], num_classes=num_arousal_classes)

# Model Definition
# 1. Video Branch
video_input = Input(shape=(32, 64, 64, 1), name="video_input")
cnn = ZeroPadding3D(padding=(1, 1, 1))(video_input)
cnn = Conv3D(32, (3, 3, 3), activation='relu')(cnn)
cnn = MaxPooling3D((2, 2, 2))(cnn)
cnn = BatchNormalization()(cnn)
cnn = Conv3D(64, (3, 3, 3), activation='relu')(cnn)
cnn = MaxPooling3D((2, 2, 2))(cnn)
cnn = BatchNormalization()(cnn)
cnn = Flatten()(cnn)
cnn_output = Dense(128, activation='relu')(cnn)

# 2. EEG Branch
eeg_input = Input(shape=(5, 512), name="eeg_input")
lstm_eeg = LSTM(128, return_sequences=True)(eeg_input)
lstm_eeg = Dropout(0.2)(lstm_eeg)
lstm_eeg = LSTM(64)(lstm_eeg)
lstm_eeg_output = Dense(128, activation='relu')(lstm_eeg)

# 3. ECG Branch
ecg_input = Input(shape=(2, 512), name="ecg_input")
lstm_ecg = LSTM(64, return_sequences=True)(ecg_input)
lstm_ecg = Dropout(0.2)(lstm_ecg)
lstm_ecg = LSTM(32)(lstm_ecg)
lstm_ecg_output = Dense(64, activation='relu')(lstm_ecg)

# Combine all modalities
combined = Concatenate()([cnn_output, lstm_eeg_output, lstm_ecg_output])
combined = Dense(256, activation='relu')(combined)
combined = Dropout(0.3)(combined)
combined = Dense(128, activation='relu')(combined)
combined = Dropout(0.2)(combined)

# Output layers
valence_output = Dense(num_valence_classes, activation='softmax', name="valence_output")(combined)
arousal_output = Dense(num_arousal_classes, activation='softmax', name="arousal_output")(combined)

# Create and compile model
model = Model(
    inputs=[video_input, eeg_input, ecg_input],
    outputs=[valence_output, arousal_output]
)

model.compile(
    optimizer='adam',
    loss=['categorical_crossentropy', 'categorical_crossentropy'],
    metrics=['accuracy','accuracy']
)

model.summary()

# Train model
history = model.fit(
    [X_video_train[..., np.newaxis], X_eeg_train, X_ecg_train],
    [y_valence_train, y_arousal_train],
    validation_data=(
        [X_video_test[..., np.newaxis], X_eeg_test, X_ecg_test],
        [y_valence_test, y_arousal_test]
    ),
    epochs=50,
    batch_size=128
)

# Evaluate model
y_valence_pred, y_arousal_pred = model.predict([X_video_test[..., np.newaxis], X_eeg_test, X_ecg_test])

# Calculate metrics
y_valence_pred_classes = np.argmax(y_valence_pred, axis=1)
y_arousal_pred_classes = np.argmax(y_arousal_pred, axis=1)
y_valence_true = np.argmax(y_valence_test, axis=1)
y_arousal_true = np.argmax(y_arousal_test, axis=1)

valence_accuracy = accuracy_score(y_valence_true, y_valence_pred_classes)
arousal_accuracy = accuracy_score(y_arousal_true, y_arousal_pred_classes)

print(f"Valence Accuracy: {valence_accuracy * 100:.2f}%")
print(f"Arousal Accuracy: {arousal_accuracy * 100:.2f}%")
# Out:
# Number of samples after duplication: 558
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ video_input         │ (None, 32, 64,    │          0 │ -                 │
# │ (InputLayer)        │ 64, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding3d      │ (None, 34, 66,    │          0 │ video_input[0][0] │
# │ (ZeroPadding3D)     │ 66, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d (Conv3D)     │ (None, 32, 64,    │        896 │ zero_padding3d[0… │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d       │ (None, 16, 32,    │          0 │ conv3d[0][0]      │
# │ (MaxPooling3D)      │ 32, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 16, 32,    │        128 │ max_pooling3d[0]… │
# │ (BatchNormalizatio… │ 32, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_1 (Conv3D)   │ (None, 14, 30,    │     55,360 │ batch_normalizat… │
# │                     │ 30, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ eeg_input           │ (None, 5, 512)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ecg_input           │ (None, 2, 512)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_1     │ (None, 7, 15, 15, │          0 │ conv3d_1[0][0]    │
# │ (MaxPooling3D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 5, 128)    │    328,192 │ eeg_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 2, 64)     │    147,712 │ ecg_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 15, 15, │        256 │ max_pooling3d_1[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 5, 128)    │          0 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 2, 64)     │          0 │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 100800)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 64)        │     49,408 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ (None, 32)        │     12,416 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │ 12,902,528 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │      8,320 │ lstm_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      2,112 │ lstm_3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 320)       │          0 │ dense[0][0],      │
# │ (Concatenate)       │                   │            │ dense_1[0][0],    │
# │                     │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256)       │     82,176 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │     32,896 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ valence_output      │ (None, 10)        │      1,290 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ arousal_output      │ (None, 10)        │      1,290 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 13,624,980 (51.98 MB)
#  Trainable params: 13,624,788 (51.97 MB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 799ms/step - arousal_output_accuracy: 0.0949 - arousal_output_loss: 7.2794 - loss: 14.0158 - valence_output_accuracy: 0.1549 - valence_output_loss: 6.6362 - val_arousal_output_accuracy: 0.1238 - val_arousal_output_loss: 10.1203 - val_loss: 24.8914 - val_valence_output_accuracy: 0.1393 - val_valence_output_loss: 14.6338
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 685ms/step - arousal_output_accuracy: 0.1423 - arousal_output_loss: 2.1979 - loss: 4.3563 - valence_output_accuracy: 0.2039 - valence_output_loss: 2.1571 - val_arousal_output_accuracy: 0.1796 - val_arousal_output_loss: 13.5836 - val_loss: 27.4280 - val_valence_output_accuracy: 0.1455 - val_valence_output_loss: 13.7250
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 626ms/step - arousal_output_accuracy: 0.1788 - arousal_output_loss: 2.1462 - loss: 4.2481 - valence_output_accuracy: 0.2330 - valence_output_loss: 2.0972 - val_arousal_output_accuracy: 0.1331 - val_arousal_output_loss: 11.1200 - val_loss: 19.4800 - val_valence_output_accuracy: 0.2043 - val_valence_output_loss: 8.4577
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 636ms/step - arousal_output_accuracy: 0.2082 - arousal_output_loss: 2.0615 - loss: 4.1082 - valence_output_accuracy: 0.2198 - valence_output_loss: 2.0490 - val_arousal_output_accuracy: 0.1765 - val_arousal_output_loss: 6.0719 - val_loss: 11.1233 - val_valence_output_accuracy: 0.2198 - val_valence_output_loss: 5.1576
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 630ms/step - arousal_output_accuracy: 0.2346 - arousal_output_loss: 2.0375 - loss: 4.0467 - valence_output_accuracy: 0.2447 - valence_output_loss: 2.0116 - val_arousal_output_accuracy: 0.1269 - val_arousal_output_loss: 3.6275 - val_loss: 6.5736 - val_valence_output_accuracy: 0.2291 - val_valence_output_loss: 3.0235
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 634ms/step - arousal_output_accuracy: 0.2704 - arousal_output_loss: 1.9446 - loss: 3.8683 - valence_output_accuracy: 0.3056 - valence_output_loss: 1.9234 - val_arousal_output_accuracy: 0.1362 - val_arousal_output_loss: 2.7352 - val_loss: 4.9684 - val_valence_output_accuracy: 0.2260 - val_valence_output_loss: 2.2309
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 636ms/step - arousal_output_accuracy: 0.2876 - arousal_output_loss: 1.8809 - loss: 3.7712 - valence_output_accuracy: 0.3056 - valence_output_loss: 1.8875 - val_arousal_output_accuracy: 0.1765 - val_arousal_output_loss: 2.1076 - val_loss: 4.1109 - val_valence_output_accuracy: 0.2663 - val_valence_output_loss: 1.9776
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 640ms/step - arousal_output_accuracy: 0.3052 - arousal_output_loss: 1.8714 - loss: 3.7019 - valence_output_accuracy: 0.3232 - valence_output_loss: 1.8315 - val_arousal_output_accuracy: 0.2291 - val_arousal_output_loss: 2.0058 - val_loss: 4.0345 - val_valence_output_accuracy: 0.2446 - val_valence_output_loss: 2.0186
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 641ms/step - arousal_output_accuracy: 0.3451 - arousal_output_loss: 1.7794 - loss: 3.5480 - valence_output_accuracy: 0.3821 - valence_output_loss: 1.7709 - val_arousal_output_accuracy: 0.3808 - val_arousal_output_loss: 1.7631 - val_loss: 3.4885 - val_valence_output_accuracy: 0.3963 - val_valence_output_loss: 1.7060
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 646ms/step - arousal_output_accuracy: 0.3694 - arousal_output_loss: 1.7213 - loss: 3.3626 - valence_output_accuracy: 0.4152 - valence_output_loss: 1.6364 - val_arousal_output_accuracy: 0.3777 - val_arousal_output_loss: 1.6151 - val_loss: 3.2200 - val_valence_output_accuracy: 0.4675 - val_valence_output_loss: 1.5897
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 713ms/step - arousal_output_accuracy: 0.4024 - arousal_output_loss: 1.6738 - loss: 3.2236 - valence_output_accuracy: 0.4439 - valence_output_loss: 1.5574 - val_arousal_output_accuracy: 0.4985 - val_arousal_output_loss: 1.4776 - val_loss: 2.9234 - val_valence_output_accuracy: 0.4644 - val_valence_output_loss: 1.4285
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 651ms/step - arousal_output_accuracy: 0.4823 - arousal_output_loss: 1.5017 - loss: 2.9061 - valence_output_accuracy: 0.4864 - valence_output_loss: 1.3977 - val_arousal_output_accuracy: 0.5542 - val_arousal_output_loss: 1.3708 - val_loss: 2.6668 - val_valence_output_accuracy: 0.5697 - val_valence_output_loss: 1.2827
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 656ms/step - arousal_output_accuracy: 0.5235 - arousal_output_loss: 1.3657 - loss: 2.6320 - valence_output_accuracy: 0.5528 - valence_output_loss: 1.2662 - val_arousal_output_accuracy: 0.4427 - val_arousal_output_loss: 1.4313 - val_loss: 2.7584 - val_valence_output_accuracy: 0.5697 - val_valence_output_loss: 1.3288
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 653ms/step - arousal_output_accuracy: 0.5109 - arousal_output_loss: 1.3128 - loss: 2.5329 - valence_output_accuracy: 0.5448 - valence_output_loss: 1.2267 - val_arousal_output_accuracy: 0.5077 - val_arousal_output_loss: 1.2722 - val_loss: 2.6682 - val_valence_output_accuracy: 0.5294 - val_valence_output_loss: 1.3797
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 713ms/step - arousal_output_accuracy: 0.5760 - arousal_output_loss: 1.1903 - loss: 2.4691 - valence_output_accuracy: 0.5315 - valence_output_loss: 1.2662 - val_arousal_output_accuracy: 0.5418 - val_arousal_output_loss: 1.2140 - val_loss: 2.4091 - val_valence_output_accuracy: 0.5759 - val_valence_output_loss: 1.1995
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 649ms/step - arousal_output_accuracy: 0.5798 - arousal_output_loss: 1.1684 - loss: 2.2629 - valence_output_accuracy: 0.6068 - valence_output_loss: 1.0838 - val_arousal_output_accuracy: 0.6625 - val_arousal_output_loss: 0.9471 - val_loss: 1.9224 - val_valence_output_accuracy: 0.6471 - val_valence_output_loss: 0.9744
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 648ms/step - arousal_output_accuracy: 0.6229 - arousal_output_loss: 1.0776 - loss: 2.0900 - valence_output_accuracy: 0.6447 - valence_output_loss: 0.9979 - val_arousal_output_accuracy: 0.6409 - val_arousal_output_loss: 0.9803 - val_loss: 1.9010 - val_valence_output_accuracy: 0.6594 - val_valence_output_loss: 0.9392
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 644ms/step - arousal_output_accuracy: 0.6193 - arousal_output_loss: 1.0794 - loss: 2.0313 - valence_output_accuracy: 0.6368 - valence_output_loss: 0.9574 - val_arousal_output_accuracy: 0.6935 - val_arousal_output_loss: 0.9112 - val_loss: 1.8712 - val_valence_output_accuracy: 0.6656 - val_valence_output_loss: 0.9652
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 644ms/step - arousal_output_accuracy: 0.6437 - arousal_output_loss: 0.9686 - loss: 1.8906 - valence_output_accuracy: 0.6486 - valence_output_loss: 0.9180 - val_arousal_output_accuracy: 0.7059 - val_arousal_output_loss: 0.8221 - val_loss: 1.6412 - val_valence_output_accuracy: 0.7337 - val_valence_output_loss: 0.8310
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 647ms/step - arousal_output_accuracy: 0.6952 - arousal_output_loss: 0.8856 - loss: 1.7325 - valence_output_accuracy: 0.6960 - valence_output_loss: 0.8460 - val_arousal_output_accuracy: 0.6997 - val_arousal_output_loss: 0.7996 - val_loss: 1.5243 - val_valence_output_accuracy: 0.7090 - val_valence_output_loss: 0.7383
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 654ms/step - arousal_output_accuracy: 0.6934 - arousal_output_loss: 0.8590 - loss: 1.6929 - valence_output_accuracy: 0.7023 - valence_output_loss: 0.8155 - val_arousal_output_accuracy: 0.7461 - val_arousal_output_loss: 0.7074 - val_loss: 1.3170 - val_valence_output_accuracy: 0.7771 - val_valence_output_loss: 0.6176
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 653ms/step - arousal_output_accuracy: 0.7094 - arousal_output_loss: 0.7885 - loss: 1.4711 - valence_output_accuracy: 0.7630 - valence_output_loss: 0.6917 - val_arousal_output_accuracy: 0.7399 - val_arousal_output_loss: 0.7009 - val_loss: 1.2998 - val_valence_output_accuracy: 0.7988 - val_valence_output_loss: 0.6071
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 651ms/step - arousal_output_accuracy: 0.7132 - arousal_output_loss: 0.7734 - loss: 1.5300 - valence_output_accuracy: 0.7158 - valence_output_loss: 0.7542 - val_arousal_output_accuracy: 0.7957 - val_arousal_output_loss: 0.6002 - val_loss: 1.2260 - val_valence_output_accuracy: 0.7957 - val_valence_output_loss: 0.6340
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 716ms/step - arousal_output_accuracy: 0.7291 - arousal_output_loss: 0.7178 - loss: 1.4560 - valence_output_accuracy: 0.7274 - valence_output_loss: 0.7429 - val_arousal_output_accuracy: 0.7740 - val_arousal_output_loss: 0.5486 - val_loss: 1.0425 - val_valence_output_accuracy: 0.8452 - val_valence_output_loss: 0.4911
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 710ms/step - arousal_output_accuracy: 0.7470 - arousal_output_loss: 0.7120 - loss: 1.3488 - valence_output_accuracy: 0.7582 - valence_output_loss: 0.6389 - val_arousal_output_accuracy: 0.7957 - val_arousal_output_loss: 0.5444 - val_loss: 1.1347 - val_valence_output_accuracy: 0.7740 - val_valence_output_loss: 0.5882
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 646ms/step - arousal_output_accuracy: 0.7756 - arousal_output_loss: 0.6416 - loss: 1.2534 - valence_output_accuracy: 0.7858 - valence_output_loss: 0.6108 - val_arousal_output_accuracy: 0.7647 - val_arousal_output_loss: 0.5860 - val_loss: 1.1365 - val_valence_output_accuracy: 0.8204 - val_valence_output_loss: 0.5478
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 646ms/step - arousal_output_accuracy: 0.7441 - arousal_output_loss: 0.6823 - loss: 1.2865 - valence_output_accuracy: 0.7701 - valence_output_loss: 0.5897 - val_arousal_output_accuracy: 0.8019 - val_arousal_output_loss: 0.4695 - val_loss: 0.8945 - val_valence_output_accuracy: 0.8638 - val_valence_output_loss: 0.4129
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 717ms/step - arousal_output_accuracy: 0.7878 - arousal_output_loss: 0.5780 - loss: 1.1170 - valence_output_accuracy: 0.7968 - valence_output_loss: 0.5375 - val_arousal_output_accuracy: 0.7802 - val_arousal_output_loss: 0.5587 - val_loss: 0.9915 - val_valence_output_accuracy: 0.8576 - val_valence_output_loss: 0.4171
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 712ms/step - arousal_output_accuracy: 0.7919 - arousal_output_loss: 0.5630 - loss: 1.0575 - valence_output_accuracy: 0.8214 - valence_output_loss: 0.4948 - val_arousal_output_accuracy: 0.8111 - val_arousal_output_loss: 0.4728 - val_loss: 0.9889 - val_valence_output_accuracy: 0.8297 - val_valence_output_loss: 0.5047
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 648ms/step - arousal_output_accuracy: 0.7763 - arousal_output_loss: 0.6158 - loss: 1.1817 - valence_output_accuracy: 0.8059 - valence_output_loss: 0.5654 - val_arousal_output_accuracy: 0.7337 - val_arousal_output_loss: 0.7259 - val_loss: 1.1510 - val_valence_output_accuracy: 0.8390 - val_valence_output_loss: 0.4294
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 647ms/step - arousal_output_accuracy: 0.7353 - arousal_output_loss: 0.7464 - loss: 1.3388 - valence_output_accuracy: 0.7597 - valence_output_loss: 0.5906 - val_arousal_output_accuracy: 0.8328 - val_arousal_output_loss: 0.4831 - val_loss: 0.9329 - val_valence_output_accuracy: 0.8359 - val_valence_output_loss: 0.4261
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 654ms/step - arousal_output_accuracy: 0.8039 - arousal_output_loss: 0.5647 - loss: 1.0809 - valence_output_accuracy: 0.8061 - valence_output_loss: 0.5174 - val_arousal_output_accuracy: 0.8173 - val_arousal_output_loss: 0.6155 - val_loss: 0.9683 - val_valence_output_accuracy: 0.9040 - val_valence_output_loss: 0.3412
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 650ms/step - arousal_output_accuracy: 0.8185 - arousal_output_loss: 0.5361 - loss: 1.0199 - valence_output_accuracy: 0.8176 - valence_output_loss: 0.4721 - val_arousal_output_accuracy: 0.8328 - val_arousal_output_loss: 0.3662 - val_loss: 0.6951 - val_valence_output_accuracy: 0.9040 - val_valence_output_loss: 0.3209
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 648ms/step - arousal_output_accuracy: 0.8147 - arousal_output_loss: 0.4941 - loss: 0.9449 - valence_output_accuracy: 0.8431 - valence_output_loss: 0.4477 - val_arousal_output_accuracy: 0.8576 - val_arousal_output_loss: 0.3224 - val_loss: 0.6124 - val_valence_output_accuracy: 0.9102 - val_valence_output_loss: 0.2813
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 711ms/step - arousal_output_accuracy: 0.8162 - arousal_output_loss: 0.5246 - loss: 0.9476 - valence_output_accuracy: 0.8509 - valence_output_loss: 0.4336 - val_arousal_output_accuracy: 0.9133 - val_arousal_output_loss: 0.3058 - val_loss: 0.5854 - val_valence_output_accuracy: 0.9257 - val_valence_output_loss: 0.2605
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 651ms/step - arousal_output_accuracy: 0.8376 - arousal_output_loss: 0.4702 - loss: 0.8373 - valence_output_accuracy: 0.8566 - valence_output_loss: 0.3837 - val_arousal_output_accuracy: 0.9226 - val_arousal_output_loss: 0.2505 - val_loss: 0.4885 - val_valence_output_accuracy: 0.9288 - val_valence_output_loss: 0.2273
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 649ms/step - arousal_output_accuracy: 0.8505 - arousal_output_loss: 0.4203 - loss: 0.8369 - valence_output_accuracy: 0.8457 - valence_output_loss: 0.4186 - val_arousal_output_accuracy: 0.8885 - val_arousal_output_loss: 0.3013 - val_loss: 0.5934 - val_valence_output_accuracy: 0.9164 - val_valence_output_loss: 0.2869
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 649ms/step - arousal_output_accuracy: 0.8443 - arousal_output_loss: 0.4074 - loss: 0.8268 - valence_output_accuracy: 0.8620 - valence_output_loss: 0.4150 - val_arousal_output_accuracy: 0.9195 - val_arousal_output_loss: 0.2403 - val_loss: 0.5000 - val_valence_output_accuracy: 0.9040 - val_valence_output_loss: 0.2505
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 650ms/step - arousal_output_accuracy: 0.8716 - arousal_output_loss: 0.3350 - loss: 0.6948 - valence_output_accuracy: 0.8591 - valence_output_loss: 0.3656 - val_arousal_output_accuracy: 0.8947 - val_arousal_output_loss: 0.2883 - val_loss: 0.5226 - val_valence_output_accuracy: 0.9133 - val_valence_output_loss: 0.2363
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 714ms/step - arousal_output_accuracy: 0.8573 - arousal_output_loss: 0.3944 - loss: 0.8013 - valence_output_accuracy: 0.8544 - valence_output_loss: 0.4007 - val_arousal_output_accuracy: 0.9195 - val_arousal_output_loss: 0.2467 - val_loss: 0.4626 - val_valence_output_accuracy: 0.9257 - val_valence_output_loss: 0.2059
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 650ms/step - arousal_output_accuracy: 0.8590 - arousal_output_loss: 0.3526 - loss: 0.6826 - valence_output_accuracy: 0.8817 - valence_output_loss: 0.3230 - val_arousal_output_accuracy: 0.9350 - val_arousal_output_loss: 0.1854 - val_loss: 0.3801 - val_valence_output_accuracy: 0.9505 - val_valence_output_loss: 0.1806
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 648ms/step - arousal_output_accuracy: 0.9045 - arousal_output_loss: 0.2946 - loss: 0.5679 - valence_output_accuracy: 0.9081 - valence_output_loss: 0.2710 - val_arousal_output_accuracy: 0.9474 - val_arousal_output_loss: 0.1550 - val_loss: 0.3463 - val_valence_output_accuracy: 0.9319 - val_valence_output_loss: 0.1787
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 648ms/step - arousal_output_accuracy: 0.8907 - arousal_output_loss: 0.2939 - loss: 0.5575 - valence_output_accuracy: 0.9090 - valence_output_loss: 0.2582 - val_arousal_output_accuracy: 0.9536 - val_arousal_output_loss: 0.1487 - val_loss: 0.3074 - val_valence_output_accuracy: 0.9474 - val_valence_output_loss: 0.1412
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 653ms/step - arousal_output_accuracy: 0.9000 - arousal_output_loss: 0.2750 - loss: 0.4795 - valence_output_accuracy: 0.9246 - valence_output_loss: 0.2091 - val_arousal_output_accuracy: 0.9319 - val_arousal_output_loss: 0.1872 - val_loss: 0.3695 - val_valence_output_accuracy: 0.9412 - val_valence_output_loss: 0.1692
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 651ms/step - arousal_output_accuracy: 0.8937 - arousal_output_loss: 0.3004 - loss: 0.5505 - valence_output_accuracy: 0.9167 - valence_output_loss: 0.2553 - val_arousal_output_accuracy: 0.9288 - val_arousal_output_loss: 0.1851 - val_loss: 0.5650 - val_valence_output_accuracy: 0.8885 - val_valence_output_loss: 0.3699
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 646ms/step - arousal_output_accuracy: 0.8765 - arousal_output_loss: 0.3360 - loss: 0.6991 - valence_output_accuracy: 0.8678 - valence_output_loss: 0.3625 - val_arousal_output_accuracy: 0.9381 - val_arousal_output_loss: 0.1623 - val_loss: 0.3265 - val_valence_output_accuracy: 0.9474 - val_valence_output_loss: 0.1473
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 648ms/step - arousal_output_accuracy: 0.8965 - arousal_output_loss: 0.2872 - loss: 0.5434 - valence_output_accuracy: 0.9099 - valence_output_loss: 0.2519 - val_arousal_output_accuracy: 0.9319 - val_arousal_output_loss: 0.2071 - val_loss: 0.3980 - val_valence_output_accuracy: 0.9319 - val_valence_output_loss: 0.1664
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 654ms/step - arousal_output_accuracy: 0.8925 - arousal_output_loss: 0.2763 - loss: 0.5230 - valence_output_accuracy: 0.9164 - valence_output_loss: 0.2457 - val_arousal_output_accuracy: 0.9628 - val_arousal_output_loss: 0.1132 - val_loss: 0.2501 - val_valence_output_accuracy: 0.9474 - val_valence_output_loss: 0.1292
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 653ms/step - arousal_output_accuracy: 0.9179 - arousal_output_loss: 0.2401 - loss: 0.4469 - valence_output_accuracy: 0.9226 - valence_output_loss: 0.2069 - val_arousal_output_accuracy: 0.9474 - val_arousal_output_loss: 0.1392 - val_loss: 0.3212 - val_valence_output_accuracy: 0.9288 - val_valence_output_loss: 0.1647
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 648ms/step - arousal_output_accuracy: 0.9043 - arousal_output_loss: 0.2591 - loss: 0.5065 - valence_output_accuracy: 0.9078 - valence_output_loss: 0.2432 - val_arousal_output_accuracy: 0.9690 - val_arousal_output_loss: 0.1049 - val_loss: 0.2457 - val_valence_output_accuracy: 0.9567 - val_valence_output_loss: 0.1283
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
# Valence Accuracy: 95.67%
# Arousal Accuracy: 96.90%

# %% [markdown]
# **Without Duplicate**

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv3D, MaxPooling3D, Flatten, Dense, LSTM, Dropout,
                                   Concatenate, BatchNormalization, ZeroPadding3D)
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils import resample
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load and duplicate dataset
data_path = '/content/drive/MyDrive/dataset/preprocessed-data/mahnob_HCI_preprocessed_all.npy'
data = np.load(data_path, allow_pickle=True)

# Extract features and labels
X_eeg = np.array([entry['eeg_data'] for entry in data])
X_video = np.array([entry['video_data'] for entry in data])
X_ecg = np.array([entry['ecg_data'] for entry in data])
y = np.array([entry['labels'] for entry in data])

print(f"Number of samples after duplication: {len(data)}")

# Pad video data if needed
if X_video.shape[1:] != (32, 64, 64):
    padded_video = []
    for video in X_video:
        pad_shape = [
            (0, max(0, 32 - video.shape[0])),
            (0, max(0, 64 - video.shape[1])),
            (0, max(0, 64 - video.shape[2]))
        ]
        padded_video.append(np.pad(video, pad_shape, mode='constant'))
    X_video = np.array(padded_video)

# Modified balance_classes function for three modalities
def balance_classes(X1, X2, X3, y, class_idx):
    labels = y[:, class_idx]
    unique_classes, class_counts = np.unique(labels, return_counts=True)
    max_count = np.max(class_counts)

    balanced_X1, balanced_X2, balanced_X3, balanced_y = [], [], [], []
    for cls in unique_classes:
        cls_mask = labels == cls
        cls_X1, cls_X2, cls_X3, cls_y = X1[cls_mask], X2[cls_mask], X3[cls_mask], y[cls_mask]

        if len(cls_y) < max_count:
            X1_oversampled, X2_oversampled, X3_oversampled, y_oversampled = resample(
                cls_X1, cls_X2, cls_X3, cls_y,
                replace=True,
                n_samples=max_count - len(cls_y),
                random_state=42
            )
            cls_X1 = np.concatenate([cls_X1, X1_oversampled])
            cls_X2 = np.concatenate([cls_X2, X2_oversampled])
            cls_X3 = np.concatenate([cls_X3, X3_oversampled])
            cls_y = np.concatenate([cls_y, y_oversampled])

        balanced_X1.append(cls_X1)
        balanced_X2.append(cls_X2)
        balanced_X3.append(cls_X3)
        balanced_y.append(cls_y)

    return (np.concatenate(balanced_X1),
            np.concatenate(balanced_X2),
            np.concatenate(balanced_X3),
            np.concatenate(balanced_y))

# Balance classes
X_eeg, X_video, X_ecg, y = balance_classes(X_eeg, X_video, X_ecg, y, class_idx=1)
X_eeg, X_video, X_ecg, y = balance_classes(X_eeg, X_video, X_ecg, y, class_idx=2)

# Split data
X_eeg_train, X_eeg_test, X_video_train, X_video_test, X_ecg_train, X_ecg_test, y_train, y_test = train_test_split(
    X_eeg, X_video, X_ecg, y, test_size=0.2, random_state=42
)

# Prepare labels
num_valence_classes = int(np.max(y[:, 1])) + 1
num_arousal_classes = int(np.max(y[:, 2])) + 1

y_valence_train = to_categorical(y_train[:, 1], num_classes=num_valence_classes)
y_arousal_train = to_categorical(y_train[:, 2], num_classes=num_arousal_classes)
y_valence_test = to_categorical(y_test[:, 1], num_classes=num_valence_classes)
y_arousal_test = to_categorical(y_test[:, 2], num_classes=num_arousal_classes)

# Model Definition
# 1. Video Branch
video_input = Input(shape=(32, 64, 64, 1), name="video_input")
cnn = ZeroPadding3D(padding=(1, 1, 1))(video_input)
cnn = Conv3D(32, (3, 3, 3), activation='relu')(cnn)
cnn = MaxPooling3D((2, 2, 2))(cnn)
cnn = BatchNormalization()(cnn)
cnn = Conv3D(64, (3, 3, 3), activation='relu')(cnn)
cnn = MaxPooling3D((2, 2, 2))(cnn)
cnn = BatchNormalization()(cnn)
cnn = Flatten()(cnn)
cnn_output = Dense(128, activation='relu')(cnn)

# 2. EEG Branch
eeg_input = Input(shape=(5, 512), name="eeg_input")
lstm_eeg = LSTM(128, return_sequences=True)(eeg_input)
lstm_eeg = Dropout(0.2)(lstm_eeg)
lstm_eeg = LSTM(64)(lstm_eeg)
lstm_eeg_output = Dense(128, activation='relu')(lstm_eeg)

# 3. ECG Branch
ecg_input = Input(shape=(2, 512), name="ecg_input")
lstm_ecg = LSTM(64, return_sequences=True)(ecg_input)
lstm_ecg = Dropout(0.2)(lstm_ecg)
lstm_ecg = LSTM(32)(lstm_ecg)
lstm_ecg_output = Dense(64, activation='relu')(lstm_ecg)

# Combine all modalities
combined = Concatenate()([cnn_output, lstm_eeg_output, lstm_ecg_output])
combined = Dense(256, activation='relu')(combined)
combined = Dropout(0.3)(combined)
combined = Dense(128, activation='relu')(combined)
combined = Dropout(0.2)(combined)

# Output layers
valence_output = Dense(num_valence_classes, activation='softmax', name="valence_output")(combined)
arousal_output = Dense(num_arousal_classes, activation='softmax', name="arousal_output")(combined)

# Create and compile model
model = Model(
    inputs=[video_input, eeg_input, ecg_input],
    outputs=[valence_output, arousal_output]
)

model.compile(
    optimizer='adam',
    loss=['categorical_crossentropy', 'categorical_crossentropy'],
    metrics=['accuracy','accuracy']
)

model.summary()

# Train model
history = model.fit(
    [X_video_train[..., np.newaxis], X_eeg_train, X_ecg_train],
    [y_valence_train, y_arousal_train],
    validation_data=(
        [X_video_test[..., np.newaxis], X_eeg_test, X_ecg_test],
        [y_valence_test, y_arousal_test]
    ),
    epochs=50,
    batch_size=128
)

# Evaluate model
y_valence_pred, y_arousal_pred = model.predict([X_video_test[..., np.newaxis], X_eeg_test, X_ecg_test])

# Calculate metrics
y_valence_pred_classes = np.argmax(y_valence_pred, axis=1)
y_arousal_pred_classes = np.argmax(y_arousal_pred, axis=1)
y_valence_true = np.argmax(y_valence_test, axis=1)
y_arousal_true = np.argmax(y_arousal_test, axis=1)

valence_accuracy = accuracy_score(y_valence_true, y_valence_pred_classes)
arousal_accuracy = accuracy_score(y_arousal_true, y_arousal_pred_classes)

print(f"Valence Accuracy: {valence_accuracy * 100:.2f}%")
print(f"Arousal Accuracy: {arousal_accuracy * 100:.2f}%")
# Out:
# Number of samples after duplication: 186
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ video_input         │ (None, 32, 64,    │          0 │ -                 │
# │ (InputLayer)        │ 64, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding3d_1    │ (None, 34, 66,    │          0 │ video_input[0][0] │
# │ (ZeroPadding3D)     │ 66, 1)            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_2 (Conv3D)   │ (None, 32, 64,    │        896 │ zero_padding3d_1… │
# │                     │ 64, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_2     │ (None, 16, 32,    │          0 │ conv3d_2[0][0]    │
# │ (MaxPooling3D)      │ 32, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 32,    │        128 │ max_pooling3d_2[… │
# │ (BatchNormalizatio… │ 32, 32)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_3 (Conv3D)   │ (None, 14, 30,    │     55,360 │ batch_normalizat… │
# │                     │ 30, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ eeg_input           │ (None, 5, 512)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ecg_input           │ (None, 2, 512)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_3     │ (None, 7, 15, 15, │          0 │ conv3d_3[0][0]    │
# │ (MaxPooling3D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_4 (LSTM)       │ (None, 5, 128)    │    328,192 │ eeg_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_6 (LSTM)       │ (None, 2, 64)     │    147,712 │ ecg_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 15, 15, │        256 │ max_pooling3d_3[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 5, 128)    │          0 │ lstm_4[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 2, 64)     │          0 │ lstm_6[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 100800)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_5 (LSTM)       │ (None, 64)        │     49,408 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_7 (LSTM)       │ (None, 32)        │     12,416 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │ 12,902,528 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │      8,320 │ lstm_5[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 64)        │      2,112 │ lstm_7[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 320)       │          0 │ dense_5[0][0],    │
# │ (Concatenate)       │                   │            │ dense_6[0][0],    │
# │                     │                   │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 256)       │     82,176 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 256)       │          0 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 128)       │     32,896 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128)       │          0 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ valence_output      │ (None, 10)        │      1,290 │ dropout_7[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ arousal_output      │ (None, 10)        │      1,290 │ dropout_7[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 13,624,980 (51.98 MB)
#  Trainable params: 13,624,788 (51.97 MB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - arousal_output_accuracy: 0.1450 - arousal_output_loss: 6.4190 - loss: 13.3983 - valence_output_accuracy: 0.1091 - valence_output_loss: 6.9966 - val_arousal_output_accuracy: 0.1596 - val_arousal_output_loss: 16.5947 - val_loss: 27.3515 - val_valence_output_accuracy: 0.1809 - val_valence_output_loss: 10.7568
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 701ms/step - arousal_output_accuracy: 0.1507 - arousal_output_loss: 4.8504 - loss: 9.3921 - valence_output_accuracy: 0.1314 - valence_output_loss: 4.5931 - val_arousal_output_accuracy: 0.1277 - val_arousal_output_loss: 52.4928 - val_loss: 71.8578 - val_valence_output_accuracy: 0.1596 - val_valence_output_loss: 19.3651
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 719ms/step - arousal_output_accuracy: 0.1467 - arousal_output_loss: 3.6780 - loss: 7.2931 - valence_output_accuracy: 0.1485 - valence_output_loss: 3.6016 - val_arousal_output_accuracy: 0.1383 - val_arousal_output_loss: 44.9029 - val_loss: 67.8063 - val_valence_output_accuracy: 0.1277 - val_valence_output_loss: 22.9034
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 709ms/step - arousal_output_accuracy: 0.1403 - arousal_output_loss: 2.3019 - loss: 4.5363 - valence_output_accuracy: 0.1702 - valence_output_loss: 2.2340 - val_arousal_output_accuracy: 0.1277 - val_arousal_output_loss: 56.5086 - val_loss: 88.2980 - val_valence_output_accuracy: 0.1809 - val_valence_output_loss: 31.7894
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 773ms/step - arousal_output_accuracy: 0.1444 - arousal_output_loss: 2.2965 - loss: 4.4595 - valence_output_accuracy: 0.1831 - valence_output_loss: 2.1629 - val_arousal_output_accuracy: 0.1277 - val_arousal_output_loss: 66.1824 - val_loss: 109.0895 - val_valence_output_accuracy: 0.1489 - val_valence_output_loss: 42.9071
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 773ms/step - arousal_output_accuracy: 0.1549 - arousal_output_loss: 2.2329 - loss: 4.3421 - valence_output_accuracy: 0.2150 - valence_output_loss: 2.1096 - val_arousal_output_accuracy: 0.1277 - val_arousal_output_loss: 66.8256 - val_loss: 116.1572 - val_valence_output_accuracy: 0.1489 - val_valence_output_loss: 49.3316
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 706ms/step - arousal_output_accuracy: 0.1639 - arousal_output_loss: 2.1991 - loss: 4.2460 - valence_output_accuracy: 0.2413 - valence_output_loss: 2.0465 - val_arousal_output_accuracy: 0.1809 - val_arousal_output_loss: 64.0721 - val_loss: 114.2705 - val_valence_output_accuracy: 0.1489 - val_valence_output_loss: 50.1984
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 708ms/step - arousal_output_accuracy: 0.1765 - arousal_output_loss: 2.1734 - loss: 4.1997 - valence_output_accuracy: 0.2261 - valence_output_loss: 2.0260 - val_arousal_output_accuracy: 0.1596 - val_arousal_output_loss: 58.5462 - val_loss: 105.9733 - val_valence_output_accuracy: 0.1596 - val_valence_output_loss: 47.4271
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 787ms/step - arousal_output_accuracy: 0.2383 - arousal_output_loss: 2.0702 - loss: 4.0069 - valence_output_accuracy: 0.2976 - valence_output_loss: 1.9362 - val_arousal_output_accuracy: 0.1277 - val_arousal_output_loss: 52.9899 - val_loss: 96.8826 - val_valence_output_accuracy: 0.1489 - val_valence_output_loss: 43.8927
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 782ms/step - arousal_output_accuracy: 0.2405 - arousal_output_loss: 2.0432 - loss: 3.9150 - valence_output_accuracy: 0.2976 - valence_output_loss: 1.8702 - val_arousal_output_accuracy: 0.1277 - val_arousal_output_loss: 45.4630 - val_loss: 85.3605 - val_valence_output_accuracy: 0.1489 - val_valence_output_loss: 39.8975
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 780ms/step - arousal_output_accuracy: 0.2179 - arousal_output_loss: 2.0210 - loss: 3.9369 - valence_output_accuracy: 0.2506 - valence_output_loss: 1.9158 - val_arousal_output_accuracy: 0.1277 - val_arousal_output_loss: 37.3138 - val_loss: 72.1035 - val_valence_output_accuracy: 0.1702 - val_valence_output_loss: 34.7897
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 780ms/step - arousal_output_accuracy: 0.2437 - arousal_output_loss: 1.9902 - loss: 3.8233 - valence_output_accuracy: 0.2862 - valence_output_loss: 1.8316 - val_arousal_output_accuracy: 0.1277 - val_arousal_output_loss: 32.3737 - val_loss: 63.8595 - val_valence_output_accuracy: 0.1915 - val_valence_output_loss: 31.4858
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 709ms/step - arousal_output_accuracy: 0.2826 - arousal_output_loss: 1.9453 - loss: 3.7782 - valence_output_accuracy: 0.2895 - valence_output_loss: 1.8328 - val_arousal_output_accuracy: 0.1383 - val_arousal_output_loss: 27.7478 - val_loss: 54.9367 - val_valence_output_accuracy: 0.1596 - val_valence_output_loss: 27.1889
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 797ms/step - arousal_output_accuracy: 0.2718 - arousal_output_loss: 1.9448 - loss: 3.7460 - valence_output_accuracy: 0.3129 - valence_output_loss: 1.8001 - val_arousal_output_accuracy: 0.1170 - val_arousal_output_loss: 24.2824 - val_loss: 48.2699 - val_valence_output_accuracy: 0.1596 - val_valence_output_loss: 23.9876
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 705ms/step - arousal_output_accuracy: 0.2801 - arousal_output_loss: 1.9189 - loss: 3.7130 - valence_output_accuracy: 0.3188 - valence_output_loss: 1.7935 - val_arousal_output_accuracy: 0.1170 - val_arousal_output_loss: 20.8655 - val_loss: 41.1905 - val_valence_output_accuracy: 0.1064 - val_valence_output_loss: 20.3249
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 702ms/step - arousal_output_accuracy: 0.2825 - arousal_output_loss: 1.8660 - loss: 3.6505 - valence_output_accuracy: 0.3101 - valence_output_loss: 1.7821 - val_arousal_output_accuracy: 0.1596 - val_arousal_output_loss: 17.2524 - val_loss: 33.4912 - val_valence_output_accuracy: 0.1064 - val_valence_output_loss: 16.2389
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 777ms/step - arousal_output_accuracy: 0.2829 - arousal_output_loss: 1.8206 - loss: 3.4766 - valence_output_accuracy: 0.4095 - valence_output_loss: 1.6559 - val_arousal_output_accuracy: 0.1170 - val_arousal_output_loss: 14.8210 - val_loss: 28.5303 - val_valence_output_accuracy: 0.1489 - val_valence_output_loss: 13.7093
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 777ms/step - arousal_output_accuracy: 0.3124 - arousal_output_loss: 1.7807 - loss: 3.4667 - valence_output_accuracy: 0.3571 - valence_output_loss: 1.6850 - val_arousal_output_accuracy: 0.1383 - val_arousal_output_loss: 13.3578 - val_loss: 25.1895 - val_valence_output_accuracy: 0.1383 - val_valence_output_loss: 11.8318
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 782ms/step - arousal_output_accuracy: 0.3056 - arousal_output_loss: 1.8096 - loss: 3.5272 - valence_output_accuracy: 0.3347 - valence_output_loss: 1.7149 - val_arousal_output_accuracy: 0.1064 - val_arousal_output_loss: 11.4853 - val_loss: 21.9635 - val_valence_output_accuracy: 0.1383 - val_valence_output_loss: 10.4782
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 786ms/step - arousal_output_accuracy: 0.3411 - arousal_output_loss: 1.7708 - loss: 3.4377 - valence_output_accuracy: 0.3818 - valence_output_loss: 1.6633 - val_arousal_output_accuracy: 0.1170 - val_arousal_output_loss: 9.7470 - val_loss: 19.1397 - val_valence_output_accuracy: 0.1383 - val_valence_output_loss: 9.3927
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 700ms/step - arousal_output_accuracy: 0.3661 - arousal_output_loss: 1.6893 - loss: 3.3392 - valence_output_accuracy: 0.3890 - valence_output_loss: 1.6491 - val_arousal_output_accuracy: 0.1170 - val_arousal_output_loss: 8.4561 - val_loss: 16.6564 - val_valence_output_accuracy: 0.1383 - val_valence_output_loss: 8.2003
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 695ms/step - arousal_output_accuracy: 0.3715 - arousal_output_loss: 1.6737 - loss: 3.3166 - valence_output_accuracy: 0.3936 - valence_output_loss: 1.6415 - val_arousal_output_accuracy: 0.1596 - val_arousal_output_loss: 7.3392 - val_loss: 15.0521 - val_valence_output_accuracy: 0.1383 - val_valence_output_loss: 7.7129
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 701ms/step - arousal_output_accuracy: 0.3757 - arousal_output_loss: 1.6235 - loss: 3.2265 - valence_output_accuracy: 0.4036 - valence_output_loss: 1.6008 - val_arousal_output_accuracy: 0.1489 - val_arousal_output_loss: 6.2402 - val_loss: 12.4645 - val_valence_output_accuracy: 0.1489 - val_valence_output_loss: 6.2243
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 766ms/step - arousal_output_accuracy: 0.3789 - arousal_output_loss: 1.6484 - loss: 3.2191 - valence_output_accuracy: 0.4268 - valence_output_loss: 1.5693 - val_arousal_output_accuracy: 0.2340 - val_arousal_output_loss: 5.2222 - val_loss: 10.8866 - val_valence_output_accuracy: 0.1170 - val_valence_output_loss: 5.6644
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 793ms/step - arousal_output_accuracy: 0.4195 - arousal_output_loss: 1.5446 - loss: 3.1052 - valence_output_accuracy: 0.4232 - valence_output_loss: 1.5584 - val_arousal_output_accuracy: 0.1702 - val_arousal_output_loss: 4.5892 - val_loss: 8.8919 - val_valence_output_accuracy: 0.1809 - val_valence_output_loss: 4.3028
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 696ms/step - arousal_output_accuracy: 0.4518 - arousal_output_loss: 1.5832 - loss: 3.1272 - valence_output_accuracy: 0.4274 - valence_output_loss: 1.5436 - val_arousal_output_accuracy: 0.1596 - val_arousal_output_loss: 4.6114 - val_loss: 8.7472 - val_valence_output_accuracy: 0.2234 - val_valence_output_loss: 4.1358
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 768ms/step - arousal_output_accuracy: 0.4600 - arousal_output_loss: 1.5005 - loss: 2.9982 - valence_output_accuracy: 0.4603 - valence_output_loss: 1.4978 - val_arousal_output_accuracy: 0.1596 - val_arousal_output_loss: 3.5288 - val_loss: 6.8562 - val_valence_output_accuracy: 0.2234 - val_valence_output_loss: 3.3273
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 768ms/step - arousal_output_accuracy: 0.4673 - arousal_output_loss: 1.4709 - loss: 2.9618 - valence_output_accuracy: 0.4693 - valence_output_loss: 1.4907 - val_arousal_output_accuracy: 0.2021 - val_arousal_output_loss: 3.2162 - val_loss: 6.5329 - val_valence_output_accuracy: 0.2340 - val_valence_output_loss: 3.3167
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 768ms/step - arousal_output_accuracy: 0.4672 - arousal_output_loss: 1.4209 - loss: 2.8352 - valence_output_accuracy: 0.5160 - valence_output_loss: 1.4126 - val_arousal_output_accuracy: 0.1809 - val_arousal_output_loss: 2.8725 - val_loss: 5.6811 - val_valence_output_accuracy: 0.2660 - val_valence_output_loss: 2.8086
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 789ms/step - arousal_output_accuracy: 0.4957 - arousal_output_loss: 1.3907 - loss: 2.7545 - valence_output_accuracy: 0.4877 - valence_output_loss: 1.3648 - val_arousal_output_accuracy: 0.2979 - val_arousal_output_loss: 2.7963 - val_loss: 5.7133 - val_valence_output_accuracy: 0.2660 - val_valence_output_loss: 2.9169
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 704ms/step - arousal_output_accuracy: 0.5430 - arousal_output_loss: 1.3503 - loss: 2.6638 - valence_output_accuracy: 0.5325 - valence_output_loss: 1.3151 - val_arousal_output_accuracy: 0.2766 - val_arousal_output_loss: 2.4381 - val_loss: 5.0593 - val_valence_output_accuracy: 0.3191 - val_valence_output_loss: 2.6211
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 765ms/step - arousal_output_accuracy: 0.5197 - arousal_output_loss: 1.3053 - loss: 2.6551 - valence_output_accuracy: 0.5370 - valence_output_loss: 1.3485 - val_arousal_output_accuracy: 0.2872 - val_arousal_output_loss: 2.2788 - val_loss: 4.6711 - val_valence_output_accuracy: 0.3191 - val_valence_output_loss: 2.3923
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 699ms/step - arousal_output_accuracy: 0.4838 - arousal_output_loss: 1.3366 - loss: 2.6142 - valence_output_accuracy: 0.5542 - valence_output_loss: 1.2783 - val_arousal_output_accuracy: 0.2872 - val_arousal_output_loss: 2.2736 - val_loss: 4.7807 - val_valence_output_accuracy: 0.3298 - val_valence_output_loss: 2.5071
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 767ms/step - arousal_output_accuracy: 0.5786 - arousal_output_loss: 1.1597 - loss: 2.4314 - valence_output_accuracy: 0.5401 - valence_output_loss: 1.2726 - val_arousal_output_accuracy: 0.3298 - val_arousal_output_loss: 2.1012 - val_loss: 4.2945 - val_valence_output_accuracy: 0.3830 - val_valence_output_loss: 2.1933
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 697ms/step - arousal_output_accuracy: 0.5253 - arousal_output_loss: 1.2593 - loss: 2.5064 - valence_output_accuracy: 0.5179 - valence_output_loss: 1.2458 - val_arousal_output_accuracy: 0.4149 - val_arousal_output_loss: 1.9131 - val_loss: 3.9042 - val_valence_output_accuracy: 0.4574 - val_valence_output_loss: 1.9911
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 777ms/step - arousal_output_accuracy: 0.5731 - arousal_output_loss: 1.1808 - loss: 2.3773 - valence_output_accuracy: 0.5574 - valence_output_loss: 1.1959 - val_arousal_output_accuracy: 0.4149 - val_arousal_output_loss: 1.9899 - val_loss: 4.2413 - val_valence_output_accuracy: 0.3830 - val_valence_output_loss: 2.2514
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 768ms/step - arousal_output_accuracy: 0.5808 - arousal_output_loss: 1.1570 - loss: 2.3525 - valence_output_accuracy: 0.5811 - valence_output_loss: 1.1961 - val_arousal_output_accuracy: 0.4149 - val_arousal_output_loss: 1.9117 - val_loss: 3.9583 - val_valence_output_accuracy: 0.4255 - val_valence_output_loss: 2.0466
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 701ms/step - arousal_output_accuracy: 0.6052 - arousal_output_loss: 1.1197 - loss: 2.2504 - valence_output_accuracy: 0.5733 - valence_output_loss: 1.1297 - val_arousal_output_accuracy: 0.3830 - val_arousal_output_loss: 1.8936 - val_loss: 3.8933 - val_valence_output_accuracy: 0.4149 - val_valence_output_loss: 1.9997
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 697ms/step - arousal_output_accuracy: 0.6251 - arousal_output_loss: 1.0822 - loss: 2.2496 - valence_output_accuracy: 0.5818 - valence_output_loss: 1.1674 - val_arousal_output_accuracy: 0.4149 - val_arousal_output_loss: 1.7317 - val_loss: 3.6400 - val_valence_output_accuracy: 0.4468 - val_valence_output_loss: 1.9082
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 700ms/step - arousal_output_accuracy: 0.6232 - arousal_output_loss: 1.0599 - loss: 2.1193 - valence_output_accuracy: 0.6081 - valence_output_loss: 1.0607 - val_arousal_output_accuracy: 0.4787 - val_arousal_output_loss: 1.7094 - val_loss: 3.5428 - val_valence_output_accuracy: 0.4149 - val_valence_output_loss: 1.8334
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 779ms/step - arousal_output_accuracy: 0.6234 - arousal_output_loss: 1.0710 - loss: 2.0240 - valence_output_accuracy: 0.6671 - valence_output_loss: 0.9540 - val_arousal_output_accuracy: 0.5213 - val_arousal_output_loss: 1.5340 - val_loss: 3.2254 - val_valence_output_accuracy: 0.4043 - val_valence_output_loss: 1.6915
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 701ms/step - arousal_output_accuracy: 0.6535 - arousal_output_loss: 0.9876 - loss: 1.9380 - valence_output_accuracy: 0.6272 - valence_output_loss: 0.9524 - val_arousal_output_accuracy: 0.4362 - val_arousal_output_loss: 1.5766 - val_loss: 3.3090 - val_valence_output_accuracy: 0.4574 - val_valence_output_loss: 1.7324
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 700ms/step - arousal_output_accuracy: 0.6566 - arousal_output_loss: 1.0027 - loss: 1.9239 - valence_output_accuracy: 0.6659 - valence_output_loss: 0.9225 - val_arousal_output_accuracy: 0.5319 - val_arousal_output_loss: 1.4481 - val_loss: 2.9532 - val_valence_output_accuracy: 0.4894 - val_valence_output_loss: 1.5050
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 769ms/step - arousal_output_accuracy: 0.6870 - arousal_output_loss: 0.9204 - loss: 1.7817 - valence_output_accuracy: 0.6961 - valence_output_loss: 0.8616 - val_arousal_output_accuracy: 0.4787 - val_arousal_output_loss: 1.5295 - val_loss: 3.1992 - val_valence_output_accuracy: 0.4574 - val_valence_output_loss: 1.6697
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 770ms/step - arousal_output_accuracy: 0.7178 - arousal_output_loss: 0.8435 - loss: 1.7331 - valence_output_accuracy: 0.6589 - valence_output_loss: 0.8923 - val_arousal_output_accuracy: 0.4894 - val_arousal_output_loss: 1.4009 - val_loss: 3.0995 - val_valence_output_accuracy: 0.4574 - val_valence_output_loss: 1.6986
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 770ms/step - arousal_output_accuracy: 0.7044 - arousal_output_loss: 0.8811 - loss: 1.8182 - valence_output_accuracy: 0.6525 - valence_output_loss: 0.9357 - val_arousal_output_accuracy: 0.4362 - val_arousal_output_loss: 1.5083 - val_loss: 3.0075 - val_valence_output_accuracy: 0.4468 - val_valence_output_loss: 1.4992
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 794ms/step - arousal_output_accuracy: 0.6523 - arousal_output_loss: 0.9425 - loss: 1.8603 - valence_output_accuracy: 0.6660 - valence_output_loss: 0.9167 - val_arousal_output_accuracy: 0.5851 - val_arousal_output_loss: 1.2530 - val_loss: 2.5997 - val_valence_output_accuracy: 0.5532 - val_valence_output_loss: 1.3466
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 765ms/step - arousal_output_accuracy: 0.7051 - arousal_output_loss: 0.8617 - loss: 1.7680 - valence_output_accuracy: 0.6633 - valence_output_loss: 0.9047 - val_arousal_output_accuracy: 0.5319 - val_arousal_output_loss: 1.3691 - val_loss: 2.7638 - val_valence_output_accuracy: 0.4894 - val_valence_output_loss: 1.3947
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 703ms/step - arousal_output_accuracy: 0.7197 - arousal_output_loss: 0.7176 - loss: 1.5563 - valence_output_accuracy: 0.7155 - valence_output_loss: 0.8376 - val_arousal_output_accuracy: 0.6170 - val_arousal_output_loss: 1.3030 - val_loss: 2.5507 - val_valence_output_accuracy: 0.6383 - val_valence_output_loss: 1.2476
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 700ms/step - arousal_output_accuracy: 0.6738 - arousal_output_loss: 0.8610 - loss: 1.6737 - valence_output_accuracy: 0.7090 - valence_output_loss: 0.8105 - val_arousal_output_accuracy: 0.5638 - val_arousal_output_loss: 1.2832 - val_loss: 2.6885 - val_valence_output_accuracy: 0.5000 - val_valence_output_loss: 1.4053
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# Valence Accuracy: 50.00%
# Arousal Accuracy: 56.38%
